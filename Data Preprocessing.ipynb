# %%
import scipy.io.wavfile
import scipy.signal
import numpy as np
import heartpy as hp
import pandas as pd
import matplotlib.pyplot as plt
from glob import glob
from tqdm import tqdm
import os
# Out:
# C:\Users\user\anaconda3\lib\site-packages\numpy\_distributor_init.py:30: UserWarning: loaded more than 1 DLL from .libs:
# C:\Users\user\anaconda3\lib\site-packages\numpy\.libs\libopenblas.NOIJJG62EMASZI6NYURL6JBKM4EVBGM7.gfortran-win_amd64.dll
# C:\Users\user\anaconda3\lib\site-packages\numpy\.libs\libopenblas.wcdjnk7yvmpzq2me2zzhjjrj3jikndb7.gfortran-win_amd64.dll
#   warnings.warn("loaded more than 1 DLL from .libs:\n%s" %

# %%
for k in range(1,101):
    data_url = 'D:/Data/ECGDB/' + str(k)
    save_url = "D:/Data/ECGDB_preprocessing/01. down_sampling/" + str(k)
#     os.mkdir(save_url)
    
    for i in range(1,61):
    
        file = pd.read_csv(data_url + "/{0}.csv".format(i), header=None)
        ECG_down = pd.DataFrame([file[1][j] for j in range(1,500000,195)])
        ECG_down.to_csv(save_url + "/down_sampling_{0}.csv".format(i))

# %%
ECG = pd.read_csv('D:/Data/ECGDB_preprocessing/02. down_sampling/1/down_sampling_1.csv')
ECG_r = pd.read_csv('D:/Data/ECGDB/1/1.csv')

ECG.transpose()
plt.figure(figsize=(20,4))
plt.title("Down_Sampling Data")
plt.xlabel('Frequency(Hz)')
plt.ylabel('Amplitude(mV)')
# plt.xticks(x)
plt.plot(ECG.iloc[:,1]) #신호

# %%
plt.figure(figsize=(20,4))
plt.title("ECGDB Data")
plt.xlabel('Frequency(Hz)')
plt.ylabel('Amplitude(mV)')
plt.plot(ECG_r.iloc[:,1]) #신호

# %%
for k in range(56,101):
    data_url = 'D:/Data/ECGDB/down_sampling/' + str(k)
    save_url = "D:/Data/ECGDB/Band_pass/" + str(k)
    os.mkdir(save_url)
    
    for i in range(1,61):

        file = (data_url + "/down_sampling_{0}.csv".format(i))

        ECG_bp = pd.read_csv(file, header=0)
        ECG_bpp = ECG_bp.transpose()
        # ECG = hp.scale_data(ECG)

        test = []

    #     for j in range(0,60):

        ECG_1= ECG_bpp.iloc[1]

        ECG_bandpass = hp.filter_signal(ECG_1, cutoff=[0.01, 50], sample_rate=500.0, order=3, filtertype='bandpass')


    #     plt.subplot(4, 1, 1)
    #     plt.title("origial data_{0}".format(i))
    #     plt.plot(ECG_bp.iloc[1])


    #     plt.subplot(4, 1, 3)
    #     plt.title("band_{0}".format(i))
    #     plt.plot(ECG_bandpass)


        plt.show()


#         print(file)

        test.append(ECG_bandpass)

        test = pd.DataFrame(test).transpose()
        pd.DataFrame(test).to_csv(save_url + "/ECG_bandpass_{0}.csv".format(i))
    
        
#     plt.savefig('D:/Data/ECGDB/ECG_bandpass/ECG_band_{0}.jpg'.format(i))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [10], in <cell line: 1>()
#       2 data_url = 'D:/Data/ECGDB/down_sampling/' + str(k)
#       3 save_url = "D:/Data/ECGDB/Band_pass/" + str(k)
# ----> 4 os.mkdir(save_url)
#       6 for i in range(1,61):
#       8     file = (data_url + "/down_sampling_{0}.csv".format(i))
#
# FileNotFoundError: [WinError 3] 지정된 경로를 찾을 수 없습니다: 'D:/Data/ECGDB/Band_pass/56'

# %%
ECG_band_pass= pd.read_csv('D:/Data/ECGDB_preprocessing/03. Band_pass/1/ECG_bandpass_1.csv')
ECG_band_pass = ECG_band_pass.transpose()
plt.figure(figsize=(20,4))
plt.title("Bandpass_Filter")
plt.xlabel('Frequency(Hz)')
plt.ylabel('Amplitude(mV)')
plt.plot(ECG_band_pass.iloc[1])

# %%
import wfdb
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

ECG = pd.read_csv('D:/Data/ECGDB_preprocessing/03. Band_pass/10/ECG_bandpass_28.csv')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy.signal as sig

#low-pass filter
def lpf(x):
	y = x.copy()
	
	for n in x.index:
		if(n < 12):
			continue
		y.iloc[n,1] = 2*y.iloc[n-1,1] - y.iloc[n-2,1] + x.iloc[n,1] - 2*x.iloc[n-6,1] + x.iloc[n-12,1] 
	return y

# %%
#high-pass filter
def hpf(x):
	y = x.copy()
	
	for n in x.index:
		if(n < 32):
			continue
		y.iloc[n,1] = y.iloc[n-1,1] - x.iloc[n,1]/32 + x.iloc[n-16,1] - x.iloc[n-17,1] + x.iloc[n-32,1]/32
	return y

# %%
#defivative of signal
def deriv(x):
    y = x.copy()
    
    for n in x.index:
        if(n < 4):
            continue
        y.iloc[n, 1] = (2*x.iloc[n,1] + x.iloc[n-1,1] - x.iloc[n-3,1] - 2*x.iloc[n-4,1])/4
    return y

# %%
#squarring the signal
def squaring(x):
	y = x.copy()

	for n in x.index:
		y.iloc[n,1] = x.iloc[n,1]**2
	return y

# %%
#integral of the signal for a moving window of ws size.
def win_sum(x, ws):
	y = x.copy()
	l = int(ws/2)
	
	for n in x.index:
		tmp_sum = 0
		
		if(n > 933-l):
			break

		if(n < l):
			continue
		for j in range(n-l,n+l+1):
			tmp_sum += x.iloc[j,1]
		y.iloc[n,1] = tmp_sum/(l+1)		
	return y

def detection(x):
	y = x.copy()

# %%
#Application of lpf
f1 = lpf(ECG)
#Application of hpf
f2 = hpf(f1)
#Application of the derivative
f3 = deriv(f2)
#squaring signal
f4 = squaring(f3)

window_size = 40
f5 = win_sum(f4, window_size)

# %%
plt.figure(figsize=(20,4))
plt.plot(ECG.iloc[:,1])
plt.title('Original Signal')
plt.xlabel('time')
# plt.xlim([-5, 5]) 
plt.ylabel('mV')
# Out:
# Text(0, 0.5, 'mV')

# %%
plt.figure(figsize=(20,4))
plt.plot(f2.iloc[:,0], f2.iloc[:,1])
plt.title('Band-pass Filtering')
plt.xlabel('time')
plt.ylabel('mV')
plt.plot()
# Out:
# []

# %%
# from systole.detectors import pan_tompkins, hamilton, moving_average, christov, engelse_zeelenberg
# # Load NeuroKit and other useful packages
# import neurokit2 as nk

# file = f2

# pantompkins1985 = nk.ecg_findpeaks(nk.ecg_clean(f2.iloc[:,1], method="pantompkins1985"), method="pantompkins1985")
# signals, info = nk.ecg_peaks(f2.iloc[:,1], correct_artifacts=False)
# nk.events_plot(info["ECG_R_Peaks"], f2.iloc[:,1])
        
# #         peak = pd.DataFrame(pantompkins1985)
        
# print(pantompkins1985)

# peak = pd.DataFrame(pantompkins1985)
# peak.to_csv(save_url + "/r_peak_{0}.csv".format(i))

# %%
plt.figure(figsize=(20,4))
plt.plot(f3.iloc[:,0], f3.iloc[:,1])
plt.title('Derivative')
plt.xlabel('time')
plt.ylabel('mV')
# Out:
# Text(0, 0.5, 'mV')

# %%
plt.figure(figsize=(20,4))
plt.plot(f4.iloc[:,0], f4.iloc[:,1])
plt.title('Squarring')
plt.xlabel('time')
plt.ylabel('mV')
# Out:
# Text(0, 0.5, 'mV')

# %%
plt.figure(figsize=(20,4))
plt.plot(f5.iloc[:,1])
plt.title('Pan-Tompkins algorithm')
plt.xlabel('time')
plt.ylabel('mV')
plt.show()

# %%
plt.figure(figsize=(10,4))
plt.plot(ECG.iloc[:,1])
plt.title('one_cycle')
plt.xlabel('time')
plt.xlim([200 , 500])
plt.ylabel('mV')
plt.plot()
# Out:
# []

# %%
from systole.detectors import pan_tompkins, hamilton, moving_average, christov, engelse_zeelenberg
# Load NeuroKit and other useful packages
import neurokit2 as nk

# %%
ECG1 = pd.read_csv('D:/Data/ECGDB_preprocessing/03. Band_pass/10/ECG_bandpass_28.csv')

# %%
import pandas as pd
import neurokit2 as nk
import matplotlib.pyplot as plt

ecg = nk.ecg_simulate(duration=1, sampling_rate=256)
signals = pd.DataFrame({"ECG_Raw" : ECG.iloc[:,1],"ECG_PanTompkins" : nk.ecg_clean(ECG.iloc[:,1], sampling_rate=2565, method="pantompkins1985"),})
plt.figure(figsize=(20,4))
signals.plot() 

# nk.ecg_findpeaks(ecg, sampling_rate=2565, method="promac", show=True)
# plt.plot(ECG, modality='ecg', ecg_method='pan-tompkins', backend='bokeh', show_heart_rate=True)

# cleaned = nk.ecg_clean(f2.iloc[:,1], sampling_rate=2565)
#  _, rpeaks = nk.ecg_peaks(f5.iloc[:,1], sampling_rate=2565)
# signals, waves = nk.ecg_delineate(f5.iloc[:,1], rpeaks, sampling_rate=2565)
# nk.events_plot(waves["ECG_P_Peaks"], f5.iloc[:,1]) 
# nk.events_plot(waves["ECG_T_Peaks"], f5.iloc[:,1])


pantompkins1985 = nk.ecg_findpeaks(nk.ecg_clean(ECG.iloc[:,1], method="pantompkins1985"), method="pantompkins1985")

signals, info = nk.ecg_peaks(ECG.iloc[:,1], correct_artifacts=False)
plt.figure(figsize=(20,4))
nk.events_plot(info["ECG_R_Peaks"], ECG.iloc[:,1])

# %%
print(pantompkins1985)
# Out:
# {'ECG_R_Peaks': array([ 375,  798, 1247, 1679, 1985, 2455])}

# %%
plt.figure(figsize=(10,4))
plt.plot(ECG.iloc[:,1])
plt.title('one_cycle')
plt.xlabel('time')
plt.xlim([400 , 700])
plt.ylabel('mV')
plt.plot()
# Out:
# []

# %%
for k in range(1,101):
    data_url = 'D:/Data/ECGDB/Band_pass/' + str(k)
    save_url = "D:/Data/ECGDB/R_peak/" + str(k)
    os.mkdir(save_url)
    
    for i in range(1,61):

        file = (data_url + "/ECG_bandpass_{0}.csv".format(i))

        ECG_bp = pd.read_csv(file, header=0)
#         ECG_bpp = ECG_bp.transpose()
        # ECG = hp.scale_data(ECG)

        test = []
        
        ecg = nk.ecg_simulate(duration=1, sampling_rate=2572)
        signals = pd.DataFrame({"ECG_Raw" : ECG_bp.iloc[:,1],"ECG_PanTompkins" : nk.ecg_clean(ECG_bp.iloc[:,1], sampling_rate=2565, method="pantompkins1985"),})
#         signals.plot() 


        pantompkins1985 = nk.ecg_findpeaks(nk.ecg_clean(ECG_bp.iloc[:,1], method="pantompkins1985"), method="pantompkins1985")

        signals, info = nk.ecg_peaks(ECG_bp.iloc[:,1], correct_artifacts=False)
#         nk.events_plot(info["ECG_R_Peaks"], ECG_bp.iloc[:,1]) 


        plt.show()


#         print(file)

        test.append(pantompkins1985)

#         test = pd.DataFrame(test).transpose()
        pd.DataFrame(test).to_csv(save_url + "/r_peak_{0}.csv".format(i))
        print(file)
        print(test)
        np.savetxt("r_peak.txt", test, fmt='%s', delimiter=',')
        
#     plt.savefig('D:/Data/ECGDB/ECG_bandpass/ECG_band_{0}.jpg'.format(i))
# Out:
# D:/Data/ECGDB/Band_pass/1/ECG_bandpass_1.csv
# [{'ECG_R_Peaks': array([ 353,  681, 1078, 1432, 1897, 2218])}]
# D:/Data/ECGDB/Band_pass/1/ECG_bandpass_2.csv
# [{'ECG_R_Peaks': array([ 307,  686, 1004, 1408, 1755, 2249])}]
# D:/Data/ECGDB/Band_pass/1/ECG_bandpass_3.csv
# [{'ECG_R_Peaks': array([ 306,  613,  960, 1439, 1763, 2066, 2371])}]
# D:/Data/ECGDB/Band_pass/1/ECG_bandpass_4.csv
# [{'ECG_R_Peaks': array([ 318,  643, 1125, 1519, 1829, 2244])}]
# D:/Data/ECGDB/Band_pass/1/ECG_bandpass_5.csv
# [{'ECG_R_Peaks': array([ 348,  668,  978, 1409, 1711, 2018, 2498])}]
# D:/Data/ECGDB/Band_pass/1/ECG_bandpass_6.csv
# [{'ECG_R_Peaks': array([ 313,  645, 1032, 1378, 1820, 2138])}]
# D:/Data/ECGDB/Band_pass/1/ECG_bandpass_7.csv
# [{'ECG_R_Peaks': array([ 301,  681, 1032, 1474, 1800, 2257])}]
# D:/Data/ECGDB/Band_pass/1/ECG_bandpass_8.csv
# [{'ECG_R_Peaks': array([ 314,  669,  970, 1424, 1788, 2261])}]
# D:/Data/ECGDB/Band_pass/1/ECG_bandpass_9.csv
# [{'ECG_R_Peaks': array([ 327,  723, 1038, 1496, 1807, 2118])}]
# D:/Data/ECGDB/Band_pass/1/ECG_bandpass_10.csv
# [{'ECG_R_Peaks': array([ 305,  628,  951, 1252, 1675, 1999, 2440])}]
# D:/Data/ECGDB/Band_pass/1/ECG_bandpass_11.csv
# [{'ECG_R_Peaks': array([ 323,  652, 1098, 1413, 1793, 2109, 2562])}]
# D:/Data/ECGDB/Band_pass/1/ECG_bandpass_12.csv
# [{'ECG_R_Peaks': array([ 327,  658,  968, 1274, 1704, 2020, 2484])}]
# D:/Data/ECGDB/Band_pass/1/ECG_bandpass_13.csv
# [{'ECG_R_Peaks': array([ 316,  773, 1094, 1555, 1910, 2386])}]
# D:/Data/ECGDB/Band_pass/1/ECG_bandpass_14.csv
# [{'ECG_R_Peaks': array([ 405,  747, 1227, 1573, 2021, 2351])}]
# D:/Data/ECGDB/Band_pass/1/ECG_bandpass_15.csv
# [{'ECG_R_Peaks': array([ 323,  701, 1045, 1491, 1826, 2326])}]
# D:/Data/ECGDB/Band_pass/1/ECG_bandpass_16.csv
# [{'ECG_R_Peaks': array([ 304,  651,  956, 1296, 1680, 1987, 2334])}]
# D:/Data/ECGDB/Band_pass/1/ECG_bandpass_17.csv
# [{'ECG_R_Peaks': array([ 327,  732, 1048, 1443, 1791, 2298])}]
# D:/Data/ECGDB/Band_pass/1/ECG_bandpass_18.csv
# [{'ECG_R_Peaks': array([ 387,  711, 1097, 1442, 1843, 2168, 2471])}]
# D:/Data/ECGDB/Band_pass/1/ECG_bandpass_19.csv
# [{'ECG_R_Peaks': array([ 360,  761, 1110, 1541, 1863, 2171])}]
# D:/Data/ECGDB/Band_pass/1/ECG_bandpass_20.csv
# [{'ECG_R_Peaks': array([ 365,  697, 1167, 1503, 1944, 2258])}]
# D:/Data/ECGDB/Band_pass/1/ECG_bandpass_21.csv
# [{'ECG_R_Peaks': array([ 327,  759, 1107, 1582, 2008, 2326])}]
# D:/Data/ECGDB/Band_pass/1/ECG_bandpass_22.csv
# [{'ECG_R_Peaks': array([ 330,  688, 1015, 1443, 1759, 2066, 2456])}]
# D:/Data/ECGDB/Band_pass/1/ECG_bandpass_23.csv
# [{'ECG_R_Peaks': array([ 306,  707, 1045, 1465, 1784, 2175, 2493])}]
# D:/Data/ECGDB/Band_pass/1/ECG_bandpass_24.csv
# [{'ECG_R_Peaks': array([ 307,  621,  925, 1289, 1605, 2046, 2360])}]
# D:/Data/ECGDB/Band_pass/1/ECG_bandpass_25.csv
# [{'ECG_R_Peaks': array([ 309,  635,  940, 1364, 1678, 2106, 2421])}]
# D:/Data/ECGDB/Band_pass/1/ECG_bandpass_26.csv
# [{'ECG_R_Peaks': array([ 308,  687,  993, 1413, 1720, 2178, 2483])}]
# D:/Data/ECGDB/Band_pass/1/ECG_bandpass_27.csv
# [{'ECG_R_Peaks': array([ 319,  666, 1019, 1425, 1757, 2060, 2487])}]
# D:/Data/ECGDB/Band_pass/1/ECG_bandpass_28.csv
# [{'ECG_R_Peaks': array([ 318,  686, 1008, 1318, 1733, 2043, 2485])}]
# D:/Data/ECGDB/Band_pass/1/ECG_bandpass_29.csv
# [{'ECG_R_Peaks': array([ 310,  628, 1031, 1367, 1806, 2132, 2555])}]
# D:/Data/ECGDB/Band_pass/1/ECG_bandpass_30.csv
# [{'ECG_R_Peaks': array([ 336,  642,  944, 1265, 1589, 1977, 2295])}]
# D:/Data/ECGDB/Band_pass/1/ECG_bandpass_31.csv
# [{'ECG_R_Peaks': array([ 305,  634,  964, 1352, 1654, 1957, 2366])}]
# D:/Data/ECGDB/Band_pass/1/ECG_bandpass_32.csv
# [{'ECG_R_Peaks': array([ 314,  618, 1050, 1406, 1874, 2182])}]
# D:/Data/ECGDB/Band_pass/1/ECG_bandpass_33.csv
# [{'ECG_R_Peaks': array([ 309,  623,  964, 1334, 1643, 2070, 2428])}]
# D:/Data/ECGDB/Band_pass/1/ECG_bandpass_34.csv
# [{'ECG_R_Peaks': array([ 304,  680,  990, 1361, 1669, 2077, 2385])}]
# D:/Data/ECGDB/Band_pass/1/ECG_bandpass_35.csv
# [{'ECG_R_Peaks': array([ 301,  689, 1002, 1428, 1789, 2230, 2535])}]
# D:/Data/ECGDB/Band_pass/1/ECG_bandpass_36.csv
# [{'ECG_R_Peaks': array([ 335,  762, 1078, 1380, 1826, 2166])}]
# D:/Data/ECGDB/Band_pass/1/ECG_bandpass_37.csv
# [{'ECG_R_Peaks': array([ 313,  654, 1045, 1376, 1681, 2120, 2425])}]
# D:/Data/ECGDB/Band_pass/1/ECG_bandpass_38.csv
# [{'ECG_R_Peaks': array([ 301,  724, 1085, 1485, 1803, 2270])}]
# D:/Data/ECGDB/Band_pass/1/ECG_bandpass_39.csv
# [{'ECG_R_Peaks': array([ 326,  633, 1032, 1364, 1736, 2044, 2476])}]
# D:/Data/ECGDB/Band_pass/1/ECG_bandpass_40.csv
# [{'ECG_R_Peaks': array([ 372,  737, 1186, 1505, 1890, 2232])}]
# D:/Data/ECGDB/Band_pass/1/ECG_bandpass_41.csv
# [{'ECG_R_Peaks': array([ 330,  672, 1058, 1372, 1674, 2043, 2348])}]
# D:/Data/ECGDB/Band_pass/1/ECG_bandpass_42.csv
# [{'ECG_R_Peaks': array([ 356,  689, 1069, 1374, 1774, 2082, 2468])}]
# D:/Data/ECGDB/Band_pass/1/ECG_bandpass_43.csv
# [{'ECG_R_Peaks': array([ 313,  618,  979, 1286, 1695, 1999, 2416])}]
# D:/Data/ECGDB/Band_pass/1/ECG_bandpass_44.csv
# [{'ECG_R_Peaks': array([ 310,  644, 1003, 1406, 1724, 2028, 2432])}]
# D:/Data/ECGDB/Band_pass/1/ECG_bandpass_45.csv
# [{'ECG_R_Peaks': array([ 305,  650,  979, 1289, 1689, 2024, 2326])}]
# D:/Data/ECGDB/Band_pass/1/ECG_bandpass_46.csv
# [{'ECG_R_Peaks': array([ 315,  753, 1071, 1493, 1846, 2285])}]
# D:/Data/ECGDB/Band_pass/1/ECG_bandpass_47.csv
# [{'ECG_R_Peaks': array([ 324,  652,  953, 1383, 1699, 2149, 2459])}]
# D:/Data/ECGDB/Band_pass/1/ECG_bandpass_48.csv
# [{'ECG_R_Peaks': array([ 313,  628,  938, 1362, 1696, 2139, 2467])}]
# D:/Data/ECGDB/Band_pass/1/ECG_bandpass_49.csv
# [{'ECG_R_Peaks': array([ 323,  641, 1042, 1349, 1798, 2112, 2513])}]
# D:/Data/ECGDB/Band_pass/1/ECG_bandpass_50.csv
# [{'ECG_R_Peaks': array([ 308,  717, 1023, 1444, 1754, 2175, 2492])}]
# D:/Data/ECGDB/Band_pass/1/ECG_bandpass_51.csv
# [{'ECG_R_Peaks': array([ 345,  649,  963, 1286, 1655, 1957, 2361])}]
# D:/Data/ECGDB/Band_pass/1/ECG_bandpass_52.csv
# [{'ECG_R_Peaks': array([ 334,  651, 1044, 1376, 1782, 2102, 2548])}]
# D:/Data/ECGDB/Band_pass/1/ECG_bandpass_53.csv
# [{'ECG_R_Peaks': array([ 369,  670,  971, 1426, 1760, 2215, 2543])}]
# D:/Data/ECGDB/Band_pass/1/ECG_bandpass_54.csv
# [{'ECG_R_Peaks': array([ 315,  645, 1026, 1348, 1660, 2161, 2462])}]
# D:/Data/ECGDB/Band_pass/1/ECG_bandpass_55.csv
# [{'ECG_R_Peaks': array([ 332,  634, 1005, 1306, 1835, 2137])}]
# D:/Data/ECGDB/Band_pass/1/ECG_bandpass_56.csv
# [{'ECG_R_Peaks': array([ 334,  651, 1044, 1376, 1782, 2102, 2548])}]
# D:/Data/ECGDB/Band_pass/1/ECG_bandpass_57.csv
# [{'ECG_R_Peaks': array([ 305,  650,  979, 1289, 1689, 2024, 2326])}]
# D:/Data/ECGDB/Band_pass/1/ECG_bandpass_58.csv
# [{'ECG_R_Peaks': array([ 335,  762, 1078, 1380, 1826, 2166])}]
# D:/Data/ECGDB/Band_pass/1/ECG_bandpass_59.csv
# [{'ECG_R_Peaks': array([ 330,  688, 1015, 1443, 1759, 2066, 2456])}]
# D:/Data/ECGDB/Band_pass/1/ECG_bandpass_60.csv
# [{'ECG_R_Peaks': array([ 314,  669,  970, 1424, 1788, 2261])}]
# D:/Data/ECGDB/Band_pass/2/ECG_bandpass_1.csv
# [{'ECG_R_Peaks': array([ 311,  634,  953, 1268, 1601, 2067, 2407])}]
# D:/Data/ECGDB/Band_pass/2/ECG_bandpass_2.csv
# [{'ECG_R_Peaks': array([ 319,  771, 1094, 1416, 1739, 2060, 2382])}]
# D:/Data/ECGDB/Band_pass/2/ECG_bandpass_3.csv
# [{'ECG_R_Peaks': array([ 430,  752, 1240, 1601, 1902, 2210, 2515])}]
# D:/Data/ECGDB/Band_pass/2/ECG_bandpass_4.csv
# [{'ECG_R_Peaks': array([ 325,  642,  968, 1273, 1603, 1957, 2260])}]
# D:/Data/ECGDB/Band_pass/2/ECG_bandpass_5.csv
# [{'ECG_R_Peaks': array([ 381,  691, 1003, 1338, 1669, 1990, 2308])}]
# D:/Data/ECGDB/Band_pass/2/ECG_bandpass_6.csv
# [{'ECG_R_Peaks': array([ 335,  743, 1050, 1404, 1720, 2022, 2325])}]
# D:/Data/ECGDB/Band_pass/2/ECG_bandpass_7.csv
# [{'ECG_R_Peaks': array([ 352,  660,  977, 1297, 1775, 2092, 2428])}]
# D:/Data/ECGDB/Band_pass/2/ECG_bandpass_8.csv
# [{'ECG_R_Peaks': array([ 306,  608,  917, 1224, 1531, 1838, 2276])}]
# D:/Data/ECGDB/Band_pass/2/ECG_bandpass_9.csv
# [{'ECG_R_Peaks': array([ 343,  655,  959, 1442, 1744, 2119])}]
# D:/Data/ECGDB/Band_pass/2/ECG_bandpass_10.csv
# [{'ECG_R_Peaks': array([ 344,  650,  954, 1260, 1569, 1873, 2180])}]
# D:/Data/ECGDB/Band_pass/2/ECG_bandpass_11.csv
# [{'ECG_R_Peaks': array([ 317,  645,  964, 1265, 1574, 1876, 2233])}]
# D:/Data/ECGDB/Band_pass/2/ECG_bandpass_12.csv
# [{'ECG_R_Peaks': array([ 310,  786, 1100, 1438, 1753, 2214, 2519])}]
# D:/Data/ECGDB/Band_pass/2/ECG_bandpass_13.csv
# [{'ECG_R_Peaks': array([ 305,  633,  951, 1366, 1694, 2025, 2399])}]
# D:/Data/ECGDB/Band_pass/2/ECG_bandpass_14.csv
# [{'ECG_R_Peaks': array([ 308,  633, 1045, 1349, 1654, 2019, 2332])}]
# D:/Data/ECGDB/Band_pass/2/ECG_bandpass_15.csv
# [{'ECG_R_Peaks': array([ 317,  628,  931, 1477, 1804, 2284])}]
# D:/Data/ECGDB/Band_pass/2/ECG_bandpass_16.csv
# [{'ECG_R_Peaks': array([ 301,  644, 1096, 1399, 1706, 2019, 2329])}]
# D:/Data/ECGDB/Band_pass/2/ECG_bandpass_17.csv
# [{'ECG_R_Peaks': array([ 322,  646, 1092, 1413, 1793, 2156, 2473])}]
# D:/Data/ECGDB/Band_pass/2/ECG_bandpass_18.csv
# [{'ECG_R_Peaks': array([ 301,  644,  963, 1271, 1595, 2029, 2376])}]
# D:/Data/ECGDB/Band_pass/2/ECG_bandpass_19.csv
# [{'ECG_R_Peaks': array([ 314,  639, 1005, 1333, 1653, 1958, 2402])}]
# D:/Data/ECGDB/Band_pass/2/ECG_bandpass_20.csv
# [{'ECG_R_Peaks': array([ 337,  662,  963, 1274, 1582, 2057, 2450])}]
# D:/Data/ECGDB/Band_pass/2/ECG_bandpass_21.csv
# [{'ECG_R_Peaks': array([ 351,  680, 1155, 1491, 1819, 2120])}]
# D:/Data/ECGDB/Band_pass/2/ECG_bandpass_22.csv
# [{'ECG_R_Peaks': array([ 302,  646,  975, 1283, 1774, 2131, 2459])}]
# D:/Data/ECGDB/Band_pass/2/ECG_bandpass_23.csv
# [{'ECG_R_Peaks': array([ 302,  610, 1093, 1438, 1773, 2074, 2383])}]
# D:/Data/ECGDB/Band_pass/2/ECG_bandpass_24.csv
# [{'ECG_R_Peaks': array([ 389,  736, 1063, 1368, 1843, 2181, 2487])}]
# D:/Data/ECGDB/Band_pass/2/ECG_bandpass_25.csv
# [{'ECG_R_Peaks': array([ 308,  682, 1010, 1339, 1778, 2141, 2451])}]
# D:/Data/ECGDB/Band_pass/2/ECG_bandpass_26.csv
# [{'ECG_R_Peaks': array([ 307,  620,  925, 1234, 1671, 1990, 2320])}]
# D:/Data/ECGDB/Band_pass/2/ECG_bandpass_27.csv
# [{'ECG_R_Peaks': array([ 320,  753, 1085, 1392, 1700, 2222, 2528])}]
# D:/Data/ECGDB/Band_pass/2/ECG_bandpass_28.csv
# [{'ECG_R_Peaks': array([ 316,  621, 1064, 1365, 1668, 2012, 2325])}]
# D:/Data/ECGDB/Band_pass/2/ECG_bandpass_29.csv
# [{'ECG_R_Peaks': array([ 310,  635, 1108, 1415, 1786, 2267])}]
# D:/Data/ECGDB/Band_pass/2/ECG_bandpass_30.csv
# [{'ECG_R_Peaks': array([ 315,  626,  962, 1276, 1579, 2061, 2412])}]
# D:/Data/ECGDB/Band_pass/2/ECG_bandpass_31.csv
# [{'ECG_R_Peaks': array([ 302,  727, 1059, 1459, 1767, 2070, 2538])}]
# D:/Data/ECGDB/Band_pass/2/ECG_bandpass_32.csv
# [{'ECG_R_Peaks': array([ 304,  612,  929, 1238, 1703, 2052, 2360])}]
# D:/Data/ECGDB/Band_pass/2/ECG_bandpass_33.csv
# [{'ECG_R_Peaks': array([ 305,  642, 1108, 1410, 1712, 2014, 2335])}]
# D:/Data/ECGDB/Band_pass/2/ECG_bandpass_34.csv
# [{'ECG_R_Peaks': array([ 327,  672,  975, 1285, 1756, 2113, 2447])}]
# D:/Data/ECGDB/Band_pass/2/ECG_bandpass_35.csv
# [{'ECG_R_Peaks': array([ 321,  653,  955, 1416, 1779, 2098, 2422])}]
# D:/Data/ECGDB/Band_pass/2/ECG_bandpass_36.csv
# [{'ECG_R_Peaks': array([ 304,  661,  982, 1286, 1590, 1991, 2347])}]
# D:/Data/ECGDB/Band_pass/2/ECG_bandpass_37.csv
# [{'ECG_R_Peaks': array([ 325,  732, 1039, 1343, 1689, 1997, 2298])}]
# D:/Data/ECGDB/Band_pass/2/ECG_bandpass_38.csv
# [{'ECG_R_Peaks': array([ 301,  627,  941, 1249, 1784, 2093, 2401])}]
# D:/Data/ECGDB/Band_pass/2/ECG_bandpass_39.csv
# [{'ECG_R_Peaks': array([ 324,  631, 1001, 1343, 1666, 1971, 2318])}]
# D:/Data/ECGDB/Band_pass/2/ECG_bandpass_40.csv
# [{'ECG_R_Peaks': array([ 330,  638, 1053, 1359, 1725, 2029, 2357])}]
# D:/Data/ECGDB/Band_pass/2/ECG_bandpass_41.csv
# [{'ECG_R_Peaks': array([ 357,  691, 1010, 1314, 1749, 2115, 2424])}]
# D:/Data/ECGDB/Band_pass/2/ECG_bandpass_42.csv
# [{'ECG_R_Peaks': array([ 356,  659, 1103, 1423, 1736, 2153, 2492])}]
# D:/Data/ECGDB/Band_pass/2/ECG_bandpass_43.csv
# [{'ECG_R_Peaks': array([ 326,  645,  947, 1389, 1735, 2047, 2505])}]
# D:/Data/ECGDB/Band_pass/2/ECG_bandpass_44.csv
# [{'ECG_R_Peaks': array([ 310,  622,  928, 1429, 1731, 2267])}]
# D:/Data/ECGDB/Band_pass/2/ECG_bandpass_45.csv
# [{'ECG_R_Peaks': array([ 303,  604, 1003, 1329, 1637, 2077, 2399])}]
# D:/Data/ECGDB/Band_pass/2/ECG_bandpass_46.csv
# [{'ECG_R_Peaks': array([ 322,  682, 1115, 1440, 1749, 2055, 2476])}]
# D:/Data/ECGDB/Band_pass/2/ECG_bandpass_47.csv
# [{'ECG_R_Peaks': array([ 311,  624, 1004, 1334, 1649, 1954, 2261])}]
# D:/Data/ECGDB/Band_pass/2/ECG_bandpass_48.csv
# [{'ECG_R_Peaks': array([ 319,  653,  978, 1406, 1726, 2035, 2476])}]
# D:/Data/ECGDB/Band_pass/2/ECG_bandpass_49.csv
# [{'ECG_R_Peaks': array([ 318,  648, 1113, 1463, 1789, 2090, 2395])}]
# D:/Data/ECGDB/Band_pass/2/ECG_bandpass_50.csv
# [{'ECG_R_Peaks': array([ 313,  703, 1031, 1333, 1759, 2077, 2379])}]
# D:/Data/ECGDB/Band_pass/2/ECG_bandpass_51.csv
# [{'ECG_R_Peaks': array([ 303,  663,  987, 1380, 1722, 2026, 2339])}]
# D:/Data/ECGDB/Band_pass/2/ECG_bandpass_52.csv
# [{'ECG_R_Peaks': array([ 341,  783, 1114, 1422, 1743, 2218, 2532])}]
# D:/Data/ECGDB/Band_pass/2/ECG_bandpass_53.csv
# [{'ECG_R_Peaks': array([ 335,  769, 1090, 1400, 1814, 2128, 2437])}]
# D:/Data/ECGDB/Band_pass/2/ECG_bandpass_54.csv
# [{'ECG_R_Peaks': array([ 342,  649, 1053, 1364, 1673, 2110, 2438])}]
# D:/Data/ECGDB/Band_pass/2/ECG_bandpass_55.csv
# [{'ECG_R_Peaks': array([ 321,  703, 1011, 1492, 1869, 2173])}]
# D:/Data/ECGDB/Band_pass/2/ECG_bandpass_56.csv
# [{'ECG_R_Peaks': array([ 303,  663,  987, 1380, 1722, 2026, 2339])}]
# D:/Data/ECGDB/Band_pass/2/ECG_bandpass_57.csv
# [{'ECG_R_Peaks': array([ 356,  659, 1103, 1423, 1736, 2153, 2492])}]
# D:/Data/ECGDB/Band_pass/2/ECG_bandpass_58.csv
# [{'ECG_R_Peaks': array([ 327,  672,  975, 1285, 1756, 2113, 2447])}]
# D:/Data/ECGDB/Band_pass/2/ECG_bandpass_59.csv
# [{'ECG_R_Peaks': array([ 314,  639, 1005, 1333, 1653, 1958, 2402])}]
# D:/Data/ECGDB/Band_pass/2/ECG_bandpass_60.csv
# [{'ECG_R_Peaks': array([ 352,  660,  977, 1297, 1775, 2092, 2428])}]
# D:/Data/ECGDB/Band_pass/3/ECG_bandpass_1.csv
# [{'ECG_R_Peaks': array([ 332,  700, 1009, 1420, 1905, 2321])}]
# D:/Data/ECGDB/Band_pass/3/ECG_bandpass_2.csv
# [{'ECG_R_Peaks': array([ 314,  656, 1032, 1333, 1735, 2036, 2371])}]
# D:/Data/ECGDB/Band_pass/3/ECG_bandpass_3.csv
# [{'ECG_R_Peaks': array([ 315,  672,  998, 1419, 1728, 2126, 2441])}]
# D:/Data/ECGDB/Band_pass/3/ECG_bandpass_4.csv
# [{'ECG_R_Peaks': array([ 342,  653,  993, 1298, 1700, 2005, 2357])}]
# D:/Data/ECGDB/Band_pass/3/ECG_bandpass_5.csv
# [{'ECG_R_Peaks': array([ 407,  712, 1113, 1416, 1746, 2075, 2463])}]
# D:/Data/ECGDB/Band_pass/3/ECG_bandpass_6.csv
# [{'ECG_R_Peaks': array([ 387,  711, 1069, 1381, 1771, 2078, 2479])}]
# D:/Data/ECGDB/Band_pass/3/ECG_bandpass_7.csv
# [{'ECG_R_Peaks': array([ 333,  637,  983, 1298, 1648, 1963, 2329])}]
# D:/Data/ECGDB/Band_pass/3/ECG_bandpass_8.csv
# [{'ECG_R_Peaks': array([ 310,  615, 1022, 1331, 1686, 1997, 2368])}]
# D:/Data/ECGDB/Band_pass/3/ECG_bandpass_9.csv
# [{'ECG_R_Peaks': array([ 301,  617,  966, 1273, 1662, 2069, 2463])}]
# D:/Data/ECGDB/Band_pass/3/ECG_bandpass_10.csv
# [{'ECG_R_Peaks': array([ 394,  695, 1069, 1373, 1774, 2081, 2494])}]
# D:/Data/ECGDB/Band_pass/3/ECG_bandpass_11.csv
# [{'ECG_R_Peaks': array([ 458,  869, 1170, 1558, 1885, 2244, 2551])}]
# D:/Data/ECGDB/Band_pass/3/ECG_bandpass_12.csv
# [{'ECG_R_Peaks': array([ 401,  720, 1129, 1430, 1790, 2098, 2507])}]
# D:/Data/ECGDB/Band_pass/3/ECG_bandpass_13.csv
# [{'ECG_R_Peaks': array([ 315,  668,  984, 1404, 1708, 2052, 2355])}]
# D:/Data/ECGDB/Band_pass/3/ECG_bandpass_14.csv
# [{'ECG_R_Peaks': array([ 396,  704, 1103, 1514, 1834, 2229, 2540])}]
# D:/Data/ECGDB/Band_pass/3/ECG_bandpass_15.csv
# [{'ECG_R_Peaks': array([ 355,  804, 1218, 1520, 1937, 2405])}]
# D:/Data/ECGDB/Band_pass/3/ECG_bandpass_16.csv
# [{'ECG_R_Peaks': array([ 329,  676,  994, 1352, 1668, 2063, 2367])}]
# D:/Data/ECGDB/Band_pass/3/ECG_bandpass_17.csv
# [{'ECG_R_Peaks': array([ 312,  625, 1014, 1324, 1673, 1994, 2417])}]
# D:/Data/ECGDB/Band_pass/3/ECG_bandpass_18.csv
# [{'ECG_R_Peaks': array([ 317,  714, 1020, 1387, 1841, 2149, 2491])}]
# D:/Data/ECGDB/Band_pass/3/ECG_bandpass_19.csv
# [{'ECG_R_Peaks': array([ 307,  658,  982, 1408, 1712, 2049, 2376])}]
# D:/Data/ECGDB/Band_pass/3/ECG_bandpass_20.csv
# [{'ECG_R_Peaks': array([ 323,  757, 1062, 1449, 1751, 2125, 2556])}]
# D:/Data/ECGDB/Band_pass/3/ECG_bandpass_21.csv
# [{'ECG_R_Peaks': array([ 355,  657, 1031, 1475, 1878, 2193])}]
# D:/Data/ECGDB/Band_pass/3/ECG_bandpass_22.csv
# [{'ECG_R_Peaks': array([ 368,  770, 1085, 1454, 1771, 2206])}]
# D:/Data/ECGDB/Band_pass/3/ECG_bandpass_23.csv
# [{'ECG_R_Peaks': array([ 318,  632, 1090, 1484, 1807, 2201, 2516])}]
# D:/Data/ECGDB/Band_pass/3/ECG_bandpass_24.csv
# [{'ECG_R_Peaks': array([ 309,  671,  988, 1371, 1681, 2053, 2360])}]
# D:/Data/ECGDB/Band_pass/3/ECG_bandpass_25.csv
# [{'ECG_R_Peaks': array([ 353,  710, 1013, 1357, 1767, 2169, 2475])}]
# D:/Data/ECGDB/Band_pass/3/ECG_bandpass_26.csv
# [{'ECG_R_Peaks': array([ 304,  613,  970, 1282, 1657, 1974, 2422])}]
# D:/Data/ECGDB/Band_pass/3/ECG_bandpass_27.csv
# [{'ECG_R_Peaks': array([ 331,  785, 1222, 1634, 1938, 2267])}]
# D:/Data/ECGDB/Band_pass/3/ECG_bandpass_28.csv
# [{'ECG_R_Peaks': array([ 338,  789, 1093, 1437, 1745, 2110, 2418])}]
# D:/Data/ECGDB/Band_pass/3/ECG_bandpass_29.csv
# [{'ECG_R_Peaks': array([ 304,  628,  931, 1262, 1568, 1961, 2380])}]
# D:/Data/ECGDB/Band_pass/3/ECG_bandpass_30.csv
# [{'ECG_R_Peaks': array([ 363,  754, 1058, 1470, 1859, 2160, 2518])}]
# D:/Data/ECGDB/Band_pass/3/ECG_bandpass_31.csv
# [{'ECG_R_Peaks': array([ 326,  782, 1184, 1617, 1920, 2305])}]
# D:/Data/ECGDB/Band_pass/3/ECG_bandpass_32.csv
# [{'ECG_R_Peaks': array([ 447,  759, 1160, 1465, 1831, 2148, 2528])}]
# D:/Data/ECGDB/Band_pass/3/ECG_bandpass_33.csv
# [{'ECG_R_Peaks': array([ 306,  709, 1132, 1433, 1770, 2080, 2465])}]
# D:/Data/ECGDB/Band_pass/3/ECG_bandpass_34.csv
# [{'ECG_R_Peaks': array([ 314,  619,  988, 1306, 1725, 2199])}]
# D:/Data/ECGDB/Band_pass/3/ECG_bandpass_35.csv
# [{'ECG_R_Peaks': array([ 313,  616,  963, 1281, 1636, 1946, 2271])}]
# D:/Data/ECGDB/Band_pass/3/ECG_bandpass_36.csv
# [{'ECG_R_Peaks': array([ 361,  674, 1025, 1332, 1743, 2197, 2500])}]
# D:/Data/ECGDB/Band_pass/3/ECG_bandpass_37.csv
# [{'ECG_R_Peaks': array([ 328,  766, 1074, 1476, 1777, 2177])}]
# D:/Data/ECGDB/Band_pass/3/ECG_bandpass_38.csv
# [{'ECG_R_Peaks': array([ 348,  652, 1049, 1425, 1735, 2103, 2411])}]
# D:/Data/ECGDB/Band_pass/3/ECG_bandpass_39.csv
# [{'ECG_R_Peaks': array([ 326,  723, 1025, 1375, 1679, 2054, 2419])}]
# D:/Data/ECGDB/Band_pass/3/ECG_bandpass_40.csv
# [{'ECG_R_Peaks': array([ 401,  715, 1141, 1444, 1860, 2162, 2558])}]
# D:/Data/ECGDB/Band_pass/3/ECG_bandpass_41.csv
# [{'ECG_R_Peaks': array([ 331,  746, 1175, 1559, 1872, 2222])}]
# D:/Data/ECGDB/Band_pass/3/ECG_bandpass_42.csv
# [{'ECG_R_Peaks': array([ 330,  744, 1052, 1411, 1829, 2258])}]
# D:/Data/ECGDB/Band_pass/3/ECG_bandpass_43.csv
# [{'ECG_R_Peaks': array([ 326,  742, 1044, 1385, 1699, 2096, 2464])}]
# D:/Data/ECGDB/Band_pass/3/ECG_bandpass_44.csv
# [{'ECG_R_Peaks': array([ 330,  637,  951, 1260, 1570, 1883, 2214, 2521])}]
# D:/Data/ECGDB/Band_pass/3/ECG_bandpass_45.csv
# [{'ECG_R_Peaks': array([ 385,  791, 1093, 1461, 1773, 2107, 2419])}]
# D:/Data/ECGDB/Band_pass/3/ECG_bandpass_46.csv
# [{'ECG_R_Peaks': array([ 322,  729, 1203, 1607, 2058, 2492])}]
# D:/Data/ECGDB/Band_pass/3/ECG_bandpass_47.csv
# [{'ECG_R_Peaks': array([ 307,  701, 1007, 1354, 1668, 2056, 2359])}]
# D:/Data/ECGDB/Band_pass/3/ECG_bandpass_48.csv
# [{'ECG_R_Peaks': array([ 340,  641, 1015, 1465, 1902, 2345])}]
# D:/Data/ECGDB/Band_pass/3/ECG_bandpass_49.csv
# [{'ECG_R_Peaks': array([ 423,  842, 1163, 1568, 1872, 2244])}]
# D:/Data/ECGDB/Band_pass/3/ECG_bandpass_50.csv
# [{'ECG_R_Peaks': array([ 333,  759, 1141, 1446, 1806, 2110, 2475])}]
# D:/Data/ECGDB/Band_pass/3/ECG_bandpass_51.csv
# [{'ECG_R_Peaks': array([ 358,  705, 1017, 1376, 1678, 2059, 2362])}]
# D:/Data/ECGDB/Band_pass/3/ECG_bandpass_52.csv
# [{'ECG_R_Peaks': array([ 327,  725, 1027, 1423, 1725, 2127, 2537])}]
# D:/Data/ECGDB/Band_pass/3/ECG_bandpass_53.csv
# [{'ECG_R_Peaks': array([ 313,  619,  981, 1285, 1619, 1926, 2303])}]
# D:/Data/ECGDB/Band_pass/3/ECG_bandpass_54.csv
# [{'ECG_R_Peaks': array([ 313,  722, 1164, 1466, 1836, 2153])}]
# D:/Data/ECGDB/Band_pass/3/ECG_bandpass_55.csv
# [{'ECG_R_Peaks': array([ 328,  711, 1014, 1377, 1680, 2041, 2352])}]
# D:/Data/ECGDB/Band_pass/3/ECG_bandpass_56.csv
# [{'ECG_R_Peaks': array([ 423,  842, 1163, 1568, 1872, 2244])}]
# D:/Data/ECGDB/Band_pass/3/ECG_bandpass_57.csv
# [{'ECG_R_Peaks': array([ 331,  746, 1175, 1559, 1872, 2222])}]
# D:/Data/ECGDB/Band_pass/3/ECG_bandpass_58.csv
# [{'ECG_R_Peaks': array([ 326,  782, 1184, 1617, 1920, 2305])}]
# D:/Data/ECGDB/Band_pass/3/ECG_bandpass_59.csv
# [{'ECG_R_Peaks': array([ 329,  676,  994, 1352, 1668, 2063, 2367])}]
# D:/Data/ECGDB/Band_pass/3/ECG_bandpass_60.csv
# [{'ECG_R_Peaks': array([ 310,  615, 1022, 1331, 1686, 1997, 2368])}]
# D:/Data/ECGDB/Band_pass/4/ECG_bandpass_1.csv
# [{'ECG_R_Peaks': array([ 332,  661, 1046, 1349, 1653, 1963, 2276])}]
# D:/Data/ECGDB/Band_pass/4/ECG_bandpass_2.csv
# [{'ECG_R_Peaks': array([ 306,  611,  925, 1227, 1573, 1907, 2212, 2529])}]
# D:/Data/ECGDB/Band_pass/4/ECG_bandpass_3.csv
# [{'ECG_R_Peaks': array([ 313,  644,  947, 1277, 1609, 1985, 2292])}]
# D:/Data/ECGDB/Band_pass/4/ECG_bandpass_4.csv
# [{'ECG_R_Peaks': array([ 349,  660,  988, 1327, 1712, 2020, 2348])}]
# D:/Data/ECGDB/Band_pass/4/ECG_bandpass_5.csv
# [{'ECG_R_Peaks': array([ 310,  636,  956, 1265, 1595, 1959, 2267])}]
# D:/Data/ECGDB/Band_pass/4/ECG_bandpass_6.csv
# [{'ECG_R_Peaks': array([ 340,  657, 1035, 1336, 1665, 2065, 2415])}]
# D:/Data/ECGDB/Band_pass/4/ECG_bandpass_7.csv
# [{'ECG_R_Peaks': array([ 305,  615,  958, 1296, 1676, 1978, 2331])}]
# D:/Data/ECGDB/Band_pass/4/ECG_bandpass_8.csv
# [{'ECG_R_Peaks': array([ 319,  703, 1011, 1351, 1762, 2129, 2438])}]
# D:/Data/ECGDB/Band_pass/4/ECG_bandpass_9.csv
# [{'ECG_R_Peaks': array([ 331,  666,  974, 1284, 1592, 1895, 2197, 2502])}]
# D:/Data/ECGDB/Band_pass/4/ECG_bandpass_10.csv
# [{'ECG_R_Peaks': array([ 338,  700, 1077, 1382, 1745, 2164, 2512])}]
# D:/Data/ECGDB/Band_pass/4/ECG_bandpass_11.csv
# [{'ECG_R_Peaks': array([ 332,  665, 1040, 1411, 1773, 2122, 2478])}]
# D:/Data/ECGDB/Band_pass/4/ECG_bandpass_12.csv
# [{'ECG_R_Peaks': array([ 310,  616,  930, 1262, 1563, 1908, 2256, 2562])}]
# D:/Data/ECGDB/Band_pass/4/ECG_bandpass_13.csv
# [{'ECG_R_Peaks': array([ 309,  625,  983, 1296, 1643, 1990, 2292])}]
# D:/Data/ECGDB/Band_pass/4/ECG_bandpass_14.csv
# [{'ECG_R_Peaks': array([ 335,  652, 1026, 1328, 1642, 1976, 2346])}]
# D:/Data/ECGDB/Band_pass/4/ECG_bandpass_15.csv
# [{'ECG_R_Peaks': array([ 312,  631,  957, 1326, 1677, 2047, 2350])}]
# D:/Data/ECGDB/Band_pass/4/ECG_bandpass_16.csv
# [{'ECG_R_Peaks': array([ 332,  640, 1025, 1402, 1706, 2028, 2376])}]
# D:/Data/ECGDB/Band_pass/4/ECG_bandpass_17.csv
# [{'ECG_R_Peaks': array([ 326,  641,  949, 1313, 1617, 1947, 2282])}]
# D:/Data/ECGDB/Band_pass/4/ECG_bandpass_18.csv
# [{'ECG_R_Peaks': array([ 344,  729, 1037, 1371, 1741, 2047, 2392])}]
# D:/Data/ECGDB/Band_pass/4/ECG_bandpass_19.csv
# [{'ECG_R_Peaks': array([ 327,  660,  979, 1355, 1661, 1993, 2336])}]
# D:/Data/ECGDB/Band_pass/4/ECG_bandpass_20.csv
# [{'ECG_R_Peaks': array([ 309,  659, 1000, 1307, 1655, 2009, 2315])}]
# D:/Data/ECGDB/Band_pass/4/ECG_bandpass_21.csv
# [{'ECG_R_Peaks': array([ 335,  674,  991, 1360, 1721, 2084, 2390])}]
# D:/Data/ECGDB/Band_pass/4/ECG_bandpass_22.csv
# [{'ECG_R_Peaks': array([ 376,  740, 1046, 1397, 1700, 2016, 2324])}]
# D:/Data/ECGDB/Band_pass/4/ECG_bandpass_23.csv
# [{'ECG_R_Peaks': array([ 304,  647, 1007, 1365, 1728, 2088, 2461])}]
# D:/Data/ECGDB/Band_pass/4/ECG_bandpass_24.csv
# [{'ECG_R_Peaks': array([ 313,  641,  942, 1266, 1583, 1911, 2303])}]
# D:/Data/ECGDB/Band_pass/4/ECG_bandpass_25.csv
# [{'ECG_R_Peaks': array([ 316,  640,  982, 1313, 1617, 1947, 2294])}]
# D:/Data/ECGDB/Band_pass/4/ECG_bandpass_26.csv
# [{'ECG_R_Peaks': array([ 304,  607,  936, 1254, 1572, 1878, 2212, 2560])}]
# D:/Data/ECGDB/Band_pass/4/ECG_bandpass_27.csv
# [{'ECG_R_Peaks': array([ 313,  638, 1088, 1411, 1776, 2144, 2521])}]
# D:/Data/ECGDB/Band_pass/4/ECG_bandpass_28.csv
# [{'ECG_R_Peaks': array([ 342,  650,  993, 1339, 1648, 1959, 2268])}]
# D:/Data/ECGDB/Band_pass/4/ECG_bandpass_29.csv
# [{'ECG_R_Peaks': array([ 316,  652,  968, 1275, 1620, 1990, 2293])}]
# D:/Data/ECGDB/Band_pass/4/ECG_bandpass_30.csv
# [{'ECG_R_Peaks': array([ 306,  641,  998, 1307, 1628, 1935, 2280])}]
# D:/Data/ECGDB/Band_pass/4/ECG_bandpass_31.csv
# [{'ECG_R_Peaks': array([ 312,  634,  936, 1241, 1618, 1993, 2367])}]
# D:/Data/ECGDB/Band_pass/4/ECG_bandpass_32.csv
# [{'ECG_R_Peaks': array([ 301,  651, 1042, 1346, 1664, 1996, 2392])}]
# D:/Data/ECGDB/Band_pass/4/ECG_bandpass_33.csv
# [{'ECG_R_Peaks': array([ 324,  633, 1015, 1323, 1671, 2032, 2335])}]
# D:/Data/ECGDB/Band_pass/4/ECG_bandpass_34.csv
# [{'ECG_R_Peaks': array([ 334,  635,  941, 1287, 1643, 1951, 2259, 2561])}]
# D:/Data/ECGDB/Band_pass/4/ECG_bandpass_35.csv
# [{'ECG_R_Peaks': array([ 415,  765, 1071, 1372, 1673, 2008, 2318])}]
# D:/Data/ECGDB/Band_pass/4/ECG_bandpass_36.csv
# [{'ECG_R_Peaks': array([ 321,  695, 1065, 1366, 1693, 2022, 2398])}]
# D:/Data/ECGDB/Band_pass/4/ECG_bandpass_37.csv
# [{'ECG_R_Peaks': array([ 313,  619,  921, 1235, 1590, 1942, 2299])}]
# D:/Data/ECGDB/Band_pass/4/ECG_bandpass_38.csv
# [{'ECG_R_Peaks': array([ 326,  642,  987, 1306, 1690, 1999, 2344])}]
# D:/Data/ECGDB/Band_pass/4/ECG_bandpass_39.csv
# [{'ECG_R_Peaks': array([ 312,  622,  949, 1289, 1591, 1904, 2211])}]
# D:/Data/ECGDB/Band_pass/4/ECG_bandpass_40.csv
# [{'ECG_R_Peaks': array([ 336,  667,  997, 1356, 1668, 2023, 2368])}]
# D:/Data/ECGDB/Band_pass/4/ECG_bandpass_41.csv
# [{'ECG_R_Peaks': array([ 309,  654, 1039, 1412, 1783, 2166, 2467])}]
# D:/Data/ECGDB/Band_pass/4/ECG_bandpass_42.csv
# [{'ECG_R_Peaks': array([ 308,  643,  971, 1274, 1585, 1908, 2281])}]
# D:/Data/ECGDB/Band_pass/4/ECG_bandpass_43.csv
# [{'ECG_R_Peaks': array([ 309,  636,  937, 1258, 1580, 1884, 2199, 2550])}]
# D:/Data/ECGDB/Band_pass/4/ECG_bandpass_44.csv
# [{'ECG_R_Peaks': array([ 328,  670,  994, 1299, 1629, 1986, 2292])}]
# D:/Data/ECGDB/Band_pass/4/ECG_bandpass_45.csv
# [{'ECG_R_Peaks': array([ 321,  626,  933, 1245, 1560, 1917, 2290])}]
# D:/Data/ECGDB/Band_pass/4/ECG_bandpass_46.csv
# [{'ECG_R_Peaks': array([ 327,  660,  963, 1296, 1611, 1965, 2402])}]
# D:/Data/ECGDB/Band_pass/4/ECG_bandpass_47.csv
# [{'ECG_R_Peaks': array([ 329,  744, 1198, 1519, 1825, 2128, 2435])}]
# D:/Data/ECGDB/Band_pass/4/ECG_bandpass_48.csv
# [{'ECG_R_Peaks': array([ 319,  658, 1030, 1443, 1765, 2146, 2452])}]
# D:/Data/ECGDB/Band_pass/4/ECG_bandpass_49.csv
# [{'ECG_R_Peaks': array([ 342,  679, 1052, 1353, 1686, 2035, 2408])}]
# D:/Data/ECGDB/Band_pass/4/ECG_bandpass_50.csv
# [{'ECG_R_Peaks': array([ 343,  646,  969, 1323, 1633, 2001, 2358])}]
# D:/Data/ECGDB/Band_pass/4/ECG_bandpass_51.csv
# [{'ECG_R_Peaks': array([ 332,  695, 1039, 1393, 1755, 2135, 2503])}]
# D:/Data/ECGDB/Band_pass/4/ECG_bandpass_52.csv
# [{'ECG_R_Peaks': array([ 333,  713, 1017, 1337, 1661, 1967, 2297])}]
# D:/Data/ECGDB/Band_pass/4/ECG_bandpass_53.csv
# [{'ECG_R_Peaks': array([ 330,  632,  964, 1269, 1637, 2074, 2475])}]
# D:/Data/ECGDB/Band_pass/4/ECG_bandpass_54.csv
# [{'ECG_R_Peaks': array([ 320,  677, 1034, 1407, 1709, 2029, 2367])}]
# D:/Data/ECGDB/Band_pass/4/ECG_bandpass_55.csv
# [{'ECG_R_Peaks': array([ 308,  665,  976, 1321, 1654, 2038, 2502])}]
# D:/Data/ECGDB/Band_pass/4/ECG_bandpass_56.csv
# [{'ECG_R_Peaks': array([ 343,  646,  969, 1323, 1633, 2001, 2358])}]
# D:/Data/ECGDB/Band_pass/4/ECG_bandpass_57.csv
# [{'ECG_R_Peaks': array([ 309,  636,  937, 1258, 1580, 1884, 2199, 2550])}]
# D:/Data/ECGDB/Band_pass/4/ECG_bandpass_58.csv
# [{'ECG_R_Peaks': array([ 334,  635,  941, 1287, 1643, 1951, 2259, 2561])}]
# D:/Data/ECGDB/Band_pass/4/ECG_bandpass_59.csv
# [{'ECG_R_Peaks': array([ 313,  641,  942, 1266, 1583, 1911, 2303])}]
# D:/Data/ECGDB/Band_pass/4/ECG_bandpass_60.csv
# [{'ECG_R_Peaks': array([ 349,  660,  988, 1327, 1712, 2020, 2348])}]
# D:/Data/ECGDB/Band_pass/5/ECG_bandpass_1.csv
# [{'ECG_R_Peaks': array([ 306,  612, 1002, 1314, 1758, 2069, 2488])}]
# D:/Data/ECGDB/Band_pass/5/ECG_bandpass_2.csv
# [{'ECG_R_Peaks': array([ 402,  729, 1128, 1457, 1875, 2178])}]
# D:/Data/ECGDB/Band_pass/5/ECG_bandpass_3.csv
# [{'ECG_R_Peaks': array([ 346,  671, 1029, 1331, 1633, 1962, 2333])}]
# D:/Data/ECGDB/Band_pass/5/ECG_bandpass_4.csv
# [{'ECG_R_Peaks': array([ 357,  667, 1003, 1418, 1835, 2245])}]
# D:/Data/ECGDB/Band_pass/5/ECG_bandpass_5.csv
# [{'ECG_R_Peaks': array([ 382,  689, 1001, 1363, 1664, 1976, 2385])}]
# D:/Data/ECGDB/Band_pass/5/ECG_bandpass_6.csv
# [{'ECG_R_Peaks': array([ 364,  670, 1027, 1341, 1713, 2018, 2392])}]
# D:/Data/ECGDB/Band_pass/5/ECG_bandpass_7.csv
# [{'ECG_R_Peaks': array([ 322,  685, 1114, 1535, 1956, 2358])}]
# D:/Data/ECGDB/Band_pass/5/ECG_bandpass_8.csv
# [{'ECG_R_Peaks': array([ 332,  662, 1011, 1382, 1768, 2196, 2502])}]
# D:/Data/ECGDB/Band_pass/5/ECG_bandpass_9.csv
# [{'ECG_R_Peaks': array([ 312,  710, 1140, 1574, 1987, 2415])}]
# D:/Data/ECGDB/Band_pass/5/ECG_bandpass_10.csv
# [{'ECG_R_Peaks': array([ 309,  647, 1059, 1467, 1866, 2257])}]
# D:/Data/ECGDB/Band_pass/5/ECG_bandpass_11.csv
# [{'ECG_R_Peaks': array([ 320,  639,  979, 1326, 1630, 1944, 2349])}]
# D:/Data/ECGDB/Band_pass/5/ECG_bandpass_12.csv
# [{'ECG_R_Peaks': array([ 317,  633,  989, 1296, 1616, 2032, 2439])}]
# D:/Data/ECGDB/Band_pass/5/ECG_bandpass_13.csv
# [{'ECG_R_Peaks': array([ 312,  633, 1051, 1434, 1738, 2089, 2507])}]
# D:/Data/ECGDB/Band_pass/5/ECG_bandpass_14.csv
# [{'ECG_R_Peaks': array([ 318,  659,  966, 1287, 1701, 2117, 2549])}]
# D:/Data/ECGDB/Band_pass/5/ECG_bandpass_15.csv
# [{'ECG_R_Peaks': array([ 350,  773, 1191, 1509, 1875, 2300])}]
# D:/Data/ECGDB/Band_pass/5/ECG_bandpass_16.csv
# [{'ECG_R_Peaks': array([ 329,  675,  979, 1287, 1679, 2090, 2521])}]
# D:/Data/ECGDB/Band_pass/5/ECG_bandpass_17.csv
# [{'ECG_R_Peaks': array([ 318,  663,  965, 1325, 1729, 2042, 2398])}]
# D:/Data/ECGDB/Band_pass/5/ECG_bandpass_18.csv
# [{'ECG_R_Peaks': array([ 344,  649,  972, 1392, 1813, 2241, 2542])}]
# D:/Data/ECGDB/Band_pass/5/ECG_bandpass_19.csv
# [{'ECG_R_Peaks': array([ 374,  685,  991, 1340, 1642, 1945, 2296])}]
# D:/Data/ECGDB/Band_pass/5/ECG_bandpass_20.csv
# [{'ECG_R_Peaks': array([ 366,  680, 1012, 1446, 1871, 2302])}]
# D:/Data/ECGDB/Band_pass/5/ECG_bandpass_21.csv
# [{'ECG_R_Peaks': array([ 407,  709, 1052, 1385, 1799, 2112, 2502])}]
# D:/Data/ECGDB/Band_pass/5/ECG_bandpass_22.csv
# [{'ECG_R_Peaks': array([ 307,  653,  972, 1351, 1747, 2054, 2356])}]
# D:/Data/ECGDB/Band_pass/5/ECG_bandpass_23.csv
# [{'ECG_R_Peaks': array([ 450,  751, 1124, 1455, 1834, 2162, 2531])}]
# D:/Data/ECGDB/Band_pass/5/ECG_bandpass_24.csv
# [{'ECG_R_Peaks': array([ 308,  659, 1090, 1393, 1724, 2042, 2433])}]
# D:/Data/ECGDB/Band_pass/5/ECG_bandpass_25.csv
# [{'ECG_R_Peaks': array([ 341,  652, 1004, 1432, 1873, 2175, 2548])}]
# D:/Data/ECGDB/Band_pass/5/ECG_bandpass_26.csv
# [{'ECG_R_Peaks': array([ 360,  799, 1110, 1478, 1784, 2177, 2485])}]
# D:/Data/ECGDB/Band_pass/5/ECG_bandpass_27.csv
# [{'ECG_R_Peaks': array([ 320,  659, 1090, 1480, 1788, 2112, 2472])}]
# D:/Data/ECGDB/Band_pass/5/ECG_bandpass_28.csv
# [{'ECG_R_Peaks': array([ 388,  797, 1213, 1516, 1857, 2279])}]
# D:/Data/ECGDB/Band_pass/5/ECG_bandpass_29.csv
# [{'ECG_R_Peaks': array([ 303,  606,  916, 1256, 1682, 1985, 2329])}]
# D:/Data/ECGDB/Band_pass/5/ECG_bandpass_30.csv
# [{'ECG_R_Peaks': array([ 365,  757, 1063, 1417, 1853, 2155, 2511])}]
# D:/Data/ECGDB/Band_pass/5/ECG_bandpass_31.csv
# [{'ECG_R_Peaks': array([ 323,  686, 1074, 1380, 1738, 2173])}]
# D:/Data/ECGDB/Band_pass/5/ECG_bandpass_32.csv
# [{'ECG_R_Peaks': array([ 306,  658,  966, 1311, 1630, 2001, 2304])}]
# D:/Data/ECGDB/Band_pass/5/ECG_bandpass_33.csv
# [{'ECG_R_Peaks': array([ 330,  641,  978, 1281, 1633, 2052, 2465])}]
# D:/Data/ECGDB/Band_pass/5/ECG_bandpass_34.csv
# [{'ECG_R_Peaks': array([ 303,  635,  938, 1293, 1710, 2120, 2437])}]
# D:/Data/ECGDB/Band_pass/5/ECG_bandpass_35.csv
# [{'ECG_R_Peaks': array([ 314,  711, 1098, 1402, 1761, 2062, 2455])}]
# D:/Data/ECGDB/Band_pass/5/ECG_bandpass_36.csv
# [{'ECG_R_Peaks': array([ 312,  613,  972, 1311, 1687, 2008, 2396])}]
# D:/Data/ECGDB/Band_pass/5/ECG_bandpass_37.csv
# [{'ECG_R_Peaks': array([ 342,  774, 1078, 1436, 1739, 2107, 2525])}]
# D:/Data/ECGDB/Band_pass/5/ECG_bandpass_38.csv
# [{'ECG_R_Peaks': array([ 315,  685,  996, 1339, 1758, 2198, 2499])}]
# D:/Data/ECGDB/Band_pass/5/ECG_bandpass_39.csv
# [{'ECG_R_Peaks': array([ 373,  684, 1037, 1345, 1720, 2022, 2384])}]
# D:/Data/ECGDB/Band_pass/5/ECG_bandpass_40.csv
# [{'ECG_R_Peaks': array([ 312,  635,  942, 1286, 1594, 1936, 2247])}]
# D:/Data/ECGDB/Band_pass/5/ECG_bandpass_41.csv
# [{'ECG_R_Peaks': array([ 304,  624,  980, 1348, 1658, 1985, 2357])}]
# D:/Data/ECGDB/Band_pass/5/ECG_bandpass_42.csv
# [{'ECG_R_Peaks': array([ 303,  631,  980, 1293, 1606, 2018, 2429])}]
# D:/Data/ECGDB/Band_pass/5/ECG_bandpass_43.csv
# [{'ECG_R_Peaks': array([ 318,  727, 1029, 1395, 1703, 2082, 2515])}]
# D:/Data/ECGDB/Band_pass/5/ECG_bandpass_44.csv
# [{'ECG_R_Peaks': array([ 301,  646,  950, 1376, 1686, 2049, 2361])}]
# D:/Data/ECGDB/Band_pass/5/ECG_bandpass_45.csv
# [{'ECG_R_Peaks': array([ 301,  611, 1019, 1390, 1700, 2015, 2374])}]
# D:/Data/ECGDB/Band_pass/5/ECG_bandpass_46.csv
# [{'ECG_R_Peaks': array([ 316,  696, 1001, 1377, 1681, 2061, 2373])}]
# D:/Data/ECGDB/Band_pass/5/ECG_bandpass_47.csv
# [{'ECG_R_Peaks': array([ 367,  673, 1025, 1350, 1731, 2041, 2423])}]
# D:/Data/ECGDB/Band_pass/5/ECG_bandpass_48.csv
# [{'ECG_R_Peaks': array([ 305,  712, 1015, 1411, 1712, 2097, 2405])}]
# D:/Data/ECGDB/Band_pass/5/ECG_bandpass_49.csv
# [{'ECG_R_Peaks': array([ 311,  683,  993, 1359, 1799, 2101, 2446])}]
# D:/Data/ECGDB/Band_pass/5/ECG_bandpass_50.csv
# [{'ECG_R_Peaks': array([ 303,  656,  977, 1348, 1649, 2009, 2445])}]
# D:/Data/ECGDB/Band_pass/5/ECG_bandpass_51.csv
# [{'ECG_R_Peaks': array([ 309,  730, 1033, 1401, 1711, 2080, 2497])}]
# D:/Data/ECGDB/Band_pass/5/ECG_bandpass_52.csv
# [{'ECG_R_Peaks': array([ 343,  745, 1051, 1432, 1804, 2113, 2418])}]
# D:/Data/ECGDB/Band_pass/5/ECG_bandpass_53.csv
# [{'ECG_R_Peaks': array([ 317,  627, 1018, 1429, 1846, 2288])}]
# D:/Data/ECGDB/Band_pass/5/ECG_bandpass_54.csv
# [{'ECG_R_Peaks': array([ 329,  688, 1005, 1370, 1791, 2191])}]
# D:/Data/ECGDB/Band_pass/5/ECG_bandpass_55.csv
# [{'ECG_R_Peaks': array([ 316,  703, 1090, 1398, 1760, 2189, 2490])}]
# D:/Data/ECGDB/Band_pass/5/ECG_bandpass_56.csv
# [{'ECG_R_Peaks': array([ 338,  668,  975, 1350, 1651, 2020, 2324])}]
# D:/Data/ECGDB/Band_pass/5/ECG_bandpass_57.csv
# [{'ECG_R_Peaks': array([ 303,  656,  977, 1348, 1649, 2009, 2445])}]
# D:/Data/ECGDB/Band_pass/5/ECG_bandpass_58.csv
# [{'ECG_R_Peaks': array([ 312,  613,  972, 1311, 1687, 2008, 2396])}]
# D:/Data/ECGDB/Band_pass/5/ECG_bandpass_59.csv
# [{'ECG_R_Peaks': array([ 318,  659,  966, 1287, 1701, 2117, 2549])}]
# D:/Data/ECGDB/Band_pass/5/ECG_bandpass_60.csv
# [{'ECG_R_Peaks': array([ 322,  685, 1114, 1535, 1956, 2358])}]
# D:/Data/ECGDB/Band_pass/6/ECG_bandpass_1.csv
# [{'ECG_R_Peaks': array([ 304,  676, 1067, 1372, 1799, 2129, 2539])}]
# D:/Data/ECGDB/Band_pass/6/ECG_bandpass_2.csv
# [{'ECG_R_Peaks': array([ 319,  663,  973, 1300, 1615, 1974, 2275])}]
# D:/Data/ECGDB/Band_pass/6/ECG_bandpass_3.csv
# [{'ECG_R_Peaks': array([ 349,  668,  973, 1415, 1737, 2138, 2471])}]
# D:/Data/ECGDB/Band_pass/6/ECG_bandpass_4.csv
# [{'ECG_R_Peaks': array([ 304,  619,  941, 1327, 1647, 2014, 2316])}]
# D:/Data/ECGDB/Band_pass/6/ECG_bandpass_5.csv
# [{'ECG_R_Peaks': array([ 318,  636,  969, 1291, 1663, 1991, 2377])}]
# D:/Data/ECGDB/Band_pass/6/ECG_bandpass_6.csv
# [{'ECG_R_Peaks': array([ 309,  646,  972, 1282, 1590, 1895, 2205])}]
# D:/Data/ECGDB/Band_pass/6/ECG_bandpass_7.csv
# [{'ECG_R_Peaks': array([ 321,  657,  975, 1368, 1687, 2084, 2402])}]
# D:/Data/ECGDB/Band_pass/6/ECG_bandpass_8.csv
# [{'ECG_R_Peaks': array([ 322,  639,  956, 1343, 1659, 2056, 2381])}]
# D:/Data/ECGDB/Band_pass/6/ECG_bandpass_9.csv
# [{'ECG_R_Peaks': array([ 305,  613,  951, 1325, 1643, 2025, 2340])}]
# D:/Data/ECGDB/Band_pass/6/ECG_bandpass_10.csv
# [{'ECG_R_Peaks': array([ 331,  683,  999, 1404, 1721, 2109, 2428])}]
# D:/Data/ECGDB/Band_pass/6/ECG_bandpass_11.csv
# [{'ECG_R_Peaks': array([ 343,  660,  974, 1352, 1654, 2032, 2338])}]
# D:/Data/ECGDB/Band_pass/6/ECG_bandpass_12.csv
# [{'ECG_R_Peaks': array([ 347,  669, 1050, 1359, 1746, 2070, 2474])}]
# D:/Data/ECGDB/Band_pass/6/ECG_bandpass_13.csv
# [{'ECG_R_Peaks': array([ 307,  617,  948, 1317, 1632, 2004, 2307])}]
# D:/Data/ECGDB/Band_pass/6/ECG_bandpass_14.csv
# [{'ECG_R_Peaks': array([ 305,  614,  943, 1268, 1583, 1937, 2256])}]
# D:/Data/ECGDB/Band_pass/6/ECG_bandpass_15.csv
# [{'ECG_R_Peaks': array([ 302,  629,  939, 1308, 1625, 1967, 2377])}]
# D:/Data/ECGDB/Band_pass/6/ECG_bandpass_16.csv
# [{'ECG_R_Peaks': array([ 315,  641,  948, 1278, 1586, 1986, 2289])}]
# D:/Data/ECGDB/Band_pass/6/ECG_bandpass_17.csv
# [{'ECG_R_Peaks': array([ 320,  707, 1012, 1371, 1681, 2042, 2348])}]
# D:/Data/ECGDB/Band_pass/6/ECG_bandpass_18.csv
# [{'ECG_R_Peaks': array([ 316,  626,  949, 1325, 1636, 2056, 2376])}]
# D:/Data/ECGDB/Band_pass/6/ECG_bandpass_19.csv
# [{'ECG_R_Peaks': array([ 302,  615,  982, 1293, 1672, 1986, 2363])}]
# D:/Data/ECGDB/Band_pass/6/ECG_bandpass_20.csv
# [{'ECG_R_Peaks': array([ 322,  743, 1049, 1419, 1729, 2157, 2514])}]
# D:/Data/ECGDB/Band_pass/6/ECG_bandpass_21.csv
# [{'ECG_R_Peaks': array([ 345,  653,  978, 1291, 1632, 1937, 2267])}]
# D:/Data/ECGDB/Band_pass/6/ECG_bandpass_22.csv
# [{'ECG_R_Peaks': array([ 312,  730, 1077, 1469, 1782, 2144, 2465])}]
# D:/Data/ECGDB/Band_pass/6/ECG_bandpass_23.csv
# [{'ECG_R_Peaks': array([ 303,  627, 1027, 1338, 1714, 2026, 2381])}]
# D:/Data/ECGDB/Band_pass/6/ECG_bandpass_24.csv
# [{'ECG_R_Peaks': array([ 322,  641,  944, 1287, 1600, 1964, 2273])}]
# D:/Data/ECGDB/Band_pass/6/ECG_bandpass_25.csv
# [{'ECG_R_Peaks': array([ 310,  652,  958, 1317, 1630, 2024, 2327])}]
# D:/Data/ECGDB/Band_pass/6/ECG_bandpass_26.csv
# [{'ECG_R_Peaks': array([ 303,  682, 1013, 1412, 1725, 2086, 2400])}]
# D:/Data/ECGDB/Band_pass/6/ECG_bandpass_27.csv
# [{'ECG_R_Peaks': array([ 329,  638, 1059, 1366, 1780, 2108, 2499])}]
# D:/Data/ECGDB/Band_pass/6/ECG_bandpass_28.csv
# [{'ECG_R_Peaks': array([ 312,  657, 1036, 1340, 1744, 2074, 2499])}]
# D:/Data/ECGDB/Band_pass/6/ECG_bandpass_29.csv
# [{'ECG_R_Peaks': array([ 309,  616,  920, 1238, 1547, 1933, 2234])}]
# D:/Data/ECGDB/Band_pass/6/ECG_bandpass_30.csv
# [{'ECG_R_Peaks': array([ 313,  658,  968, 1270, 1640, 1972, 2372])}]
# D:/Data/ECGDB/Band_pass/6/ECG_bandpass_31.csv
# [{'ECG_R_Peaks': array([ 314,  664, 1047, 1353, 1770, 2097, 2470])}]
# D:/Data/ECGDB/Band_pass/6/ECG_bandpass_32.csv
# [{'ECG_R_Peaks': array([ 319,  650,  956, 1292, 1679, 2009, 2402])}]
# D:/Data/ECGDB/Band_pass/6/ECG_bandpass_33.csv
# [{'ECG_R_Peaks': array([ 309,  624,  963, 1284, 1675, 2007, 2418])}]
# D:/Data/ECGDB/Band_pass/6/ECG_bandpass_34.csv
# [{'ECG_R_Peaks': array([ 322,  642,  944, 1322, 1650, 2031, 2363])}]
# D:/Data/ECGDB/Band_pass/6/ECG_bandpass_35.csv
# [{'ECG_R_Peaks': array([ 311,  623,  933, 1316, 1632, 2054, 2387])}]
# D:/Data/ECGDB/Band_pass/6/ECG_bandpass_36.csv
# [{'ECG_R_Peaks': array([ 317,  624, 1031, 1336, 1771, 2072, 2501])}]
# D:/Data/ECGDB/Band_pass/6/ECG_bandpass_37.csv
# [{'ECG_R_Peaks': array([ 342,  699, 1032, 1430, 1764, 2164, 2487])}]
# D:/Data/ECGDB/Band_pass/6/ECG_bandpass_38.csv
# [{'ECG_R_Peaks': array([ 329,  715, 1023, 1414, 1739, 2127, 2459])}]
# D:/Data/ECGDB/Band_pass/6/ECG_bandpass_39.csv
# [{'ECG_R_Peaks': array([ 326,  645, 1015, 1327, 1714, 2058, 2445])}]
# D:/Data/ECGDB/Band_pass/6/ECG_bandpass_40.csv
# [{'ECG_R_Peaks': array([ 304,  688, 1036, 1420, 1746, 2118, 2437])}]
# D:/Data/ECGDB/Band_pass/6/ECG_bandpass_41.csv
# [{'ECG_R_Peaks': array([ 363,  676, 1084, 1440, 1853, 2162])}]
# D:/Data/ECGDB/Band_pass/6/ECG_bandpass_42.csv
# [{'ECG_R_Peaks': array([ 302,  649, 1077, 1412, 1795, 2121, 2508])}]
# D:/Data/ECGDB/Band_pass/6/ECG_bandpass_43.csv
# [{'ECG_R_Peaks': array([ 310,  628,  929, 1259, 1640, 1960, 2344])}]
# D:/Data/ECGDB/Band_pass/6/ECG_bandpass_44.csv
# [{'ECG_R_Peaks': array([ 325,  674, 1002, 1405, 1709, 2143, 2479])}]
# D:/Data/ECGDB/Band_pass/6/ECG_bandpass_45.csv
# [{'ECG_R_Peaks': array([ 370,  767, 1097, 1478, 1786, 2216, 2521])}]
# D:/Data/ECGDB/Band_pass/6/ECG_bandpass_46.csv
# [{'ECG_R_Peaks': array([ 327,  640,  979, 1283, 1705, 2012, 2434])}]
# D:/Data/ECGDB/Band_pass/6/ECG_bandpass_47.csv
# [{'ECG_R_Peaks': array([ 346,  649,  953, 1336, 1664, 2054, 2376])}]
# D:/Data/ECGDB/Band_pass/6/ECG_bandpass_48.csv
# [{'ECG_R_Peaks': array([ 309,  638, 1030, 1333, 1747, 2075, 2450])}]
# D:/Data/ECGDB/Band_pass/6/ECG_bandpass_49.csv
# [{'ECG_R_Peaks': array([ 335,  640,  960, 1372, 1703, 2099, 2424])}]
# D:/Data/ECGDB/Band_pass/6/ECG_bandpass_50.csv
# [{'ECG_R_Peaks': array([ 325,  635, 1032, 1337, 1767, 2099, 2478])}]
# D:/Data/ECGDB/Band_pass/6/ECG_bandpass_51.csv
# [{'ECG_R_Peaks': array([ 303,  609,  923, 1321, 1626, 2069, 2406])}]
# D:/Data/ECGDB/Band_pass/6/ECG_bandpass_52.csv
# [{'ECG_R_Peaks': array([ 316,  638,  973, 1282, 1729, 2040, 2480])}]
# D:/Data/ECGDB/Band_pass/6/ECG_bandpass_53.csv
# [{'ECG_R_Peaks': array([ 325,  635, 1032, 1337, 1767, 2099, 2478])}]
# D:/Data/ECGDB/Band_pass/6/ECG_bandpass_54.csv
# [{'ECG_R_Peaks': array([ 346,  649,  953, 1336, 1664, 2054, 2376])}]
# D:/Data/ECGDB/Band_pass/6/ECG_bandpass_55.csv
# [{'ECG_R_Peaks': array([ 310,  628,  929, 1259, 1640, 1960, 2344])}]
# D:/Data/ECGDB/Band_pass/6/ECG_bandpass_56.csv
# [{'ECG_R_Peaks': array([ 329,  715, 1023, 1414, 1739, 2127, 2459])}]
# D:/Data/ECGDB/Band_pass/6/ECG_bandpass_57.csv
# [{'ECG_R_Peaks': array([ 322,  642,  944, 1322, 1650, 2031, 2363])}]
# D:/Data/ECGDB/Band_pass/6/ECG_bandpass_58.csv
# [{'ECG_R_Peaks': array([ 313,  658,  968, 1270, 1640, 1972, 2372])}]
# D:/Data/ECGDB/Band_pass/6/ECG_bandpass_59.csv
# [{'ECG_R_Peaks': array([ 303,  627, 1027, 1338, 1714, 2026, 2381])}]
# D:/Data/ECGDB/Band_pass/6/ECG_bandpass_60.csv
# [{'ECG_R_Peaks': array([ 343,  660,  974, 1352, 1654, 2032, 2338])}]
# D:/Data/ECGDB/Band_pass/7/ECG_bandpass_1.csv
# [{'ECG_R_Peaks': array([ 313,  651, 1007, 1400, 1784, 2188, 2491])}]
# D:/Data/ECGDB/Band_pass/7/ECG_bandpass_2.csv
# [{'ECG_R_Peaks': array([ 304,  675,  985, 1292, 1609, 1943, 2252])}]
# D:/Data/ECGDB/Band_pass/7/ECG_bandpass_3.csv
# [{'ECG_R_Peaks': array([ 330,  642,  974, 1281, 1596, 1996, 2300])}]
# D:/Data/ECGDB/Band_pass/7/ECG_bandpass_4.csv
# [{'ECG_R_Peaks': array([ 301,  605,  937, 1346, 1650, 1975, 2353])}]
# D:/Data/ECGDB/Band_pass/7/ECG_bandpass_5.csv
# [{'ECG_R_Peaks': array([ 344,  702, 1106, 1496, 1800, 2132, 2502])}]
# D:/Data/ECGDB/Band_pass/7/ECG_bandpass_6.csv
# [{'ECG_R_Peaks': array([ 361,  731, 1035, 1347, 1656, 1970, 2296])}]
# D:/Data/ECGDB/Band_pass/7/ECG_bandpass_7.csv
# [{'ECG_R_Peaks': array([ 302,  614,  955, 1289, 1667, 2049, 2419])}]
# D:/Data/ECGDB/Band_pass/7/ECG_bandpass_8.csv
# [{'ECG_R_Peaks': array([ 340,  710, 1082, 1465, 1844, 2211])}]
# D:/Data/ECGDB/Band_pass/7/ECG_bandpass_9.csv
# [{'ECG_R_Peaks': array([ 318,  624,  929, 1268, 1583, 1896, 2283])}]
# D:/Data/ECGDB/Band_pass/7/ECG_bandpass_10.csv
# [{'ECG_R_Peaks': array([ 335,  668,  982, 1305, 1617, 1918, 2292])}]
# D:/Data/ECGDB/Band_pass/7/ECG_bandpass_11.csv
# [{'ECG_R_Peaks': array([ 318,  648, 1010, 1318, 1639, 1944, 2261])}]
# D:/Data/ECGDB/Band_pass/7/ECG_bandpass_12.csv
# [{'ECG_R_Peaks': array([ 321,  624,  952, 1283, 1651, 2034, 2423])}]
# D:/Data/ECGDB/Band_pass/7/ECG_bandpass_13.csv
# [{'ECG_R_Peaks': array([ 335,  704, 1005, 1335, 1653, 2036, 2407])}]
# D:/Data/ECGDB/Band_pass/7/ECG_bandpass_14.csv
# [{'ECG_R_Peaks': array([ 317,  694,  997, 1331, 1671, 2033, 2392])}]
# D:/Data/ECGDB/Band_pass/7/ECG_bandpass_15.csv
# [{'ECG_R_Peaks': array([ 302,  627,  995, 1296, 1619, 1949, 2314])}]
# D:/Data/ECGDB/Band_pass/7/ECG_bandpass_16.csv
# [{'ECG_R_Peaks': array([ 368,  683,  988, 1291, 1611, 1983, 2300])}]
# D:/Data/ECGDB/Band_pass/7/ECG_bandpass_17.csv
# [{'ECG_R_Peaks': array([ 309,  636, 1017, 1320, 1649, 2003, 2400])}]
# D:/Data/ECGDB/Band_pass/7/ECG_bandpass_18.csv
# [{'ECG_R_Peaks': array([ 327,  675,  984, 1299, 1694, 2073, 2375])}]
# D:/Data/ECGDB/Band_pass/7/ECG_bandpass_19.csv
# [{'ECG_R_Peaks': array([ 375,  681, 1007, 1337, 1735, 2040, 2365])}]
# D:/Data/ECGDB/Band_pass/7/ECG_bandpass_20.csv
# [{'ECG_R_Peaks': array([ 322,  658,  990, 1388, 1793, 2177, 2543])}]
# D:/Data/ECGDB/Band_pass/7/ECG_bandpass_21.csv
# [{'ECG_R_Peaks': array([ 341,  648,  961, 1332, 1633, 1957, 2288])}]
# D:/Data/ECGDB/Band_pass/7/ECG_bandpass_22.csv
# [{'ECG_R_Peaks': array([ 361,  666,  973, 1358, 1726, 2098, 2502])}]
# D:/Data/ECGDB/Band_pass/7/ECG_bandpass_23.csv
# [{'ECG_R_Peaks': array([ 308,  639,  986, 1355, 1720, 2112, 2505])}]
# D:/Data/ECGDB/Band_pass/7/ECG_bandpass_24.csv
# [{'ECG_R_Peaks': array([ 397,  702, 1007, 1327, 1699, 2099, 2500])}]
# D:/Data/ECGDB/Band_pass/7/ECG_bandpass_25.csv
# [{'ECG_R_Peaks': array([ 331,  635,  952, 1270, 1625, 1988, 2379])}]
# D:/Data/ECGDB/Band_pass/7/ECG_bandpass_26.csv
# [{'ECG_R_Peaks': array([ 350,  706, 1012, 1344, 1658, 2014, 2397])}]
# D:/Data/ECGDB/Band_pass/7/ECG_bandpass_27.csv
# [{'ECG_R_Peaks': array([ 336,  713, 1023, 1345, 1705, 2071, 2475])}]
# D:/Data/ECGDB/Band_pass/7/ECG_bandpass_28.csv
# [{'ECG_R_Peaks': array([ 333,  636,  945, 1313, 1679, 2055, 2446])}]
# D:/Data/ECGDB/Band_pass/7/ECG_bandpass_29.csv
# [{'ECG_R_Peaks': array([ 325,  664, 1046, 1400, 1758, 2162, 2547])}]
# D:/Data/ECGDB/Band_pass/7/ECG_bandpass_30.csv
# [{'ECG_R_Peaks': array([ 305,  703, 1081, 1467, 1867, 2174, 2503])}]
# D:/Data/ECGDB/Band_pass/7/ECG_bandpass_31.csv
# [{'ECG_R_Peaks': array([ 331,  644,  946, 1253, 1629, 1996, 2382])}]
# D:/Data/ECGDB/Band_pass/7/ECG_bandpass_32.csv
# [{'ECG_R_Peaks': array([ 305,  615,  917, 1224, 1525, 1845, 2166, 2539])}]
# D:/Data/ECGDB/Band_pass/7/ECG_bandpass_33.csv
# [{'ECG_R_Peaks': array([ 307,  608,  909, 1280, 1593, 1905, 2276])}]
# D:/Data/ECGDB/Band_pass/7/ECG_bandpass_34.csv
# [{'ECG_R_Peaks': array([ 311,  647,  985, 1373, 1767, 2133, 2490])}]
# D:/Data/ECGDB/Band_pass/7/ECG_bandpass_35.csv
# [{'ECG_R_Peaks': array([ 312,  640,  958, 1259, 1582, 1911, 2294])}]
# D:/Data/ECGDB/Band_pass/7/ECG_bandpass_36.csv
# [{'ECG_R_Peaks': array([ 311,  684,  989, 1324, 1639, 1946, 2279])}]
# D:/Data/ECGDB/Band_pass/7/ECG_bandpass_37.csv
# [{'ECG_R_Peaks': array([ 364,  675,  999, 1323, 1718, 2025, 2356])}]
# D:/Data/ECGDB/Band_pass/7/ECG_bandpass_38.csv
# [{'ECG_R_Peaks': array([ 312,  631,  958, 1261, 1570, 1911, 2314])}]
# D:/Data/ECGDB/Band_pass/7/ECG_bandpass_39.csv
# [{'ECG_R_Peaks': array([ 303,  614,  999, 1367, 1756, 2154, 2537])}]
# D:/Data/ECGDB/Band_pass/7/ECG_bandpass_40.csv
# [{'ECG_R_Peaks': array([ 396,  775, 1134, 1435, 1739, 2129, 2499])}]
# D:/Data/ECGDB/Band_pass/7/ECG_bandpass_41.csv
# [{'ECG_R_Peaks': array([ 349,  722, 1024, 1331, 1640, 1942, 2353])}]
# D:/Data/ECGDB/Band_pass/7/ECG_bandpass_42.csv
# [{'ECG_R_Peaks': array([ 309,  702, 1086, 1496, 1811, 2120, 2500])}]
# D:/Data/ECGDB/Band_pass/7/ECG_bandpass_43.csv
# [{'ECG_R_Peaks': array([ 315,  626,  992, 1293, 1610, 1998, 2305])}]
# D:/Data/ECGDB/Band_pass/7/ECG_bandpass_44.csv
# [{'ECG_R_Peaks': array([ 314,  626,  966, 1345, 1737, 2042, 2380])}]
# D:/Data/ECGDB/Band_pass/7/ECG_bandpass_45.csv
# [{'ECG_R_Peaks': array([ 381,  682, 1051, 1357, 1672, 1989, 2313])}]
# D:/Data/ECGDB/Band_pass/7/ECG_bandpass_46.csv
# [{'ECG_R_Peaks': array([ 333,  640,  945, 1262, 1602, 1903, 2213])}]
# D:/Data/ECGDB/Band_pass/7/ECG_bandpass_47.csv
# [{'ECG_R_Peaks': array([ 316,  652, 1028, 1419, 1723, 2064, 2465])}]
# D:/Data/ECGDB/Band_pass/7/ECG_bandpass_48.csv
# [{'ECG_R_Peaks': array([ 316,  636,  940, 1269, 1652, 1961, 2297])}]
# D:/Data/ECGDB/Band_pass/7/ECG_bandpass_49.csv
# [{'ECG_R_Peaks': array([ 311,  612,  930, 1257, 1559, 1866, 2265])}]
# D:/Data/ECGDB/Band_pass/7/ECG_bandpass_50.csv
# [{'ECG_R_Peaks': array([ 315,  625,  958, 1335, 1643, 1970, 2326])}]
# D:/Data/ECGDB/Band_pass/7/ECG_bandpass_51.csv
# [{'ECG_R_Peaks': array([ 310,  626,  936, 1238, 1548, 1946, 2249])}]
# D:/Data/ECGDB/Band_pass/7/ECG_bandpass_52.csv
# [{'ECG_R_Peaks': array([ 318,  643, 1008, 1315, 1618, 1992, 2392])}]
# D:/Data/ECGDB/Band_pass/7/ECG_bandpass_53.csv
# [{'ECG_R_Peaks': array([ 340,  645,  952, 1258, 1567, 1921, 2230, 2531])}]
# D:/Data/ECGDB/Band_pass/7/ECG_bandpass_54.csv
# [{'ECG_R_Peaks': array([ 365,  675,  996, 1352, 1662, 1963, 2348])}]
# D:/Data/ECGDB/Band_pass/7/ECG_bandpass_55.csv
# [{'ECG_R_Peaks': array([ 323,  699, 1005, 1312, 1617, 1923, 2326])}]
# D:/Data/ECGDB/Band_pass/7/ECG_bandpass_56.csv
# [{'ECG_R_Peaks': array([ 340,  645,  952, 1258, 1567, 1921, 2230, 2531])}]
# D:/Data/ECGDB/Band_pass/7/ECG_bandpass_57.csv
# [{'ECG_R_Peaks': array([ 315,  625,  958, 1335, 1643, 1970, 2326])}]
# D:/Data/ECGDB/Band_pass/7/ECG_bandpass_58.csv
# [{'ECG_R_Peaks': array([ 312,  631,  958, 1261, 1570, 1911, 2314])}]
# D:/Data/ECGDB/Band_pass/7/ECG_bandpass_59.csv
# [{'ECG_R_Peaks': array([ 333,  636,  945, 1313, 1679, 2055, 2446])}]
# D:/Data/ECGDB/Band_pass/7/ECG_bandpass_60.csv
# [{'ECG_R_Peaks': array([ 302,  627,  995, 1296, 1619, 1949, 2314])}]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-71-aae20cf1420c> in <module>
#      21         pantompkins1985 = nk.ecg_findpeaks(nk.ecg_clean(ECG_bp.iloc[:,1], method="pantompkins1985"), method="pantompkins1985")
#      22
# ---> 23         signals, info = nk.ecg_peaks(ECG_bp.iloc[:,1], correct_artifacts=False)
#      24 #         nk.events_plot(info["ECG_R_Peaks"], ECG_bp.iloc[:,1])
#      25
#
# ~\anaconda3\lib\site-packages\neurokit2\ecg\ecg_peaks.py in ecg_peaks(ecg_cleaned, sampling_rate, method, correct_artifacts, **kwargs)
#     197
#     198     """
# --> 199     rpeaks = ecg_findpeaks(ecg_cleaned, sampling_rate=sampling_rate, method=method, **kwargs)
#     200
#     201     if correct_artifacts:
#
# ~\anaconda3\lib\site-packages\neurokit2\ecg\ecg_findpeaks.py in ecg_findpeaks(ecg_cleaned, sampling_rate, method, show, **kwargs)
#      63     try:
#      64         func = _ecg_findpeaks_findmethod(method)
# ---> 65         rpeaks = func(ecg_cleaned, sampling_rate=sampling_rate, show=show, **kwargs)
#      66     except ValueError as error:
#      67         raise error
#
# ~\anaconda3\lib\site-packages\neurokit2\ecg\ecg_findpeaks.py in _ecg_findpeaks_neurokit(signal, sampling_rate, smoothwindow, avgwindow, gradthreshweight, minlenweight, mindelay, show)
#     260     end_qrs = np.where(np.logical_and(qrs[0:-1], np.logical_not(qrs[1:])))[0]
#     261     # Throw out QRS-ends that precede first QRS-start.
# --> 262     end_qrs = end_qrs[end_qrs > beg_qrs[0]]
#     263
#     264     # Identify R-peaks within QRS (ignore QRS that are too short).
#
# IndexError: index 0 is out of bounds for axis 0 with size 0

# %%
for k in range(1,6):
    data_url = 'D:/Data/ECGDB/Band_pass/' + str(k)
    save_url = "D:/Data/ECGDB/one_cycle/" + str(k)
#     os.mkdir(save_url)
    
    for i in range(1,61):

        file = (data_url + "/ECG_bandpass_{0}.csv".format(i))
        ECG_oc = pd.read_csv(file, header=0)

        test = []

        ECG_occ= ECG_oc.iloc[:,1]
        ECG_one_cycle = ECG_occ.loc[300:600]

        test.append(ECG_one_cycle)
        pd.DataFrame(test).to_csv(save_url + "/one_cycle_{0}.csv".format(i))
        
        print(file)
        plt.show(test)
# Out:
# D:/Data/ECGDB/Band_pass/1/ECG_bandpass_1.csv
# D:/Data/ECGDB/Band_pass/1/ECG_bandpass_2.csv
# D:/Data/ECGDB/Band_pass/1/ECG_bandpass_3.csv
# D:/Data/ECGDB/Band_pass/1/ECG_bandpass_4.csv
# D:/Data/ECGDB/Band_pass/1/ECG_bandpass_5.csv
# D:/Data/ECGDB/Band_pass/1/ECG_bandpass_6.csv
# D:/Data/ECGDB/Band_pass/1/ECG_bandpass_7.csv
# D:/Data/ECGDB/Band_pass/1/ECG_bandpass_8.csv
# D:/Data/ECGDB/Band_pass/1/ECG_bandpass_9.csv
# D:/Data/ECGDB/Band_pass/1/ECG_bandpass_10.csv
# D:/Data/ECGDB/Band_pass/1/ECG_bandpass_11.csv
# D:/Data/ECGDB/Band_pass/1/ECG_bandpass_12.csv
# D:/Data/ECGDB/Band_pass/1/ECG_bandpass_13.csv
# D:/Data/ECGDB/Band_pass/1/ECG_bandpass_14.csv
# D:/Data/ECGDB/Band_pass/1/ECG_bandpass_15.csv
# D:/Data/ECGDB/Band_pass/1/ECG_bandpass_16.csv
# D:/Data/ECGDB/Band_pass/1/ECG_bandpass_17.csv
# D:/Data/ECGDB/Band_pass/1/ECG_bandpass_18.csv
# D:/Data/ECGDB/Band_pass/1/ECG_bandpass_19.csv
# D:/Data/ECGDB/Band_pass/1/ECG_bandpass_20.csv
# D:/Data/ECGDB/Band_pass/1/ECG_bandpass_21.csv
# D:/Data/ECGDB/Band_pass/1/ECG_bandpass_22.csv
# D:/Data/ECGDB/Band_pass/1/ECG_bandpass_23.csv
# D:/Data/ECGDB/Band_pass/1/ECG_bandpass_24.csv
# D:/Data/ECGDB/Band_pass/1/ECG_bandpass_25.csv
# D:/Data/ECGDB/Band_pass/1/ECG_bandpass_26.csv
# D:/Data/ECGDB/Band_pass/1/ECG_bandpass_27.csv
# D:/Data/ECGDB/Band_pass/1/ECG_bandpass_28.csv
# D:/Data/ECGDB/Band_pass/1/ECG_bandpass_29.csv
# D:/Data/ECGDB/Band_pass/1/ECG_bandpass_30.csv
# D:/Data/ECGDB/Band_pass/1/ECG_bandpass_31.csv
# D:/Data/ECGDB/Band_pass/1/ECG_bandpass_32.csv
# D:/Data/ECGDB/Band_pass/1/ECG_bandpass_33.csv
# D:/Data/ECGDB/Band_pass/1/ECG_bandpass_34.csv
# D:/Data/ECGDB/Band_pass/1/ECG_bandpass_35.csv
# D:/Data/ECGDB/Band_pass/1/ECG_bandpass_36.csv
# D:/Data/ECGDB/Band_pass/1/ECG_bandpass_37.csv
# D:/Data/ECGDB/Band_pass/1/ECG_bandpass_38.csv
# D:/Data/ECGDB/Band_pass/1/ECG_bandpass_39.csv
# D:/Data/ECGDB/Band_pass/1/ECG_bandpass_40.csv
# D:/Data/ECGDB/Band_pass/1/ECG_bandpass_41.csv
# D:/Data/ECGDB/Band_pass/1/ECG_bandpass_42.csv
# D:/Data/ECGDB/Band_pass/1/ECG_bandpass_43.csv
# D:/Data/ECGDB/Band_pass/1/ECG_bandpass_44.csv
# D:/Data/ECGDB/Band_pass/1/ECG_bandpass_45.csv
# D:/Data/ECGDB/Band_pass/1/ECG_bandpass_46.csv
# D:/Data/ECGDB/Band_pass/1/ECG_bandpass_47.csv
# D:/Data/ECGDB/Band_pass/1/ECG_bandpass_48.csv
# D:/Data/ECGDB/Band_pass/1/ECG_bandpass_49.csv
# D:/Data/ECGDB/Band_pass/1/ECG_bandpass_50.csv
# D:/Data/ECGDB/Band_pass/1/ECG_bandpass_51.csv
# D:/Data/ECGDB/Band_pass/1/ECG_bandpass_52.csv
# D:/Data/ECGDB/Band_pass/1/ECG_bandpass_53.csv
# D:/Data/ECGDB/Band_pass/1/ECG_bandpass_54.csv
# D:/Data/ECGDB/Band_pass/1/ECG_bandpass_55.csv
# D:/Data/ECGDB/Band_pass/1/ECG_bandpass_56.csv
# D:/Data/ECGDB/Band_pass/1/ECG_bandpass_57.csv
# D:/Data/ECGDB/Band_pass/1/ECG_bandpass_58.csv
# D:/Data/ECGDB/Band_pass/1/ECG_bandpass_59.csv
# D:/Data/ECGDB/Band_pass/1/ECG_bandpass_60.csv
# D:/Data/ECGDB/Band_pass/2/ECG_bandpass_1.csv
# D:/Data/ECGDB/Band_pass/2/ECG_bandpass_2.csv
# D:/Data/ECGDB/Band_pass/2/ECG_bandpass_3.csv
# D:/Data/ECGDB/Band_pass/2/ECG_bandpass_4.csv
# D:/Data/ECGDB/Band_pass/2/ECG_bandpass_5.csv
# D:/Data/ECGDB/Band_pass/2/ECG_bandpass_6.csv
# D:/Data/ECGDB/Band_pass/2/ECG_bandpass_7.csv
# D:/Data/ECGDB/Band_pass/2/ECG_bandpass_8.csv
# D:/Data/ECGDB/Band_pass/2/ECG_bandpass_9.csv
# D:/Data/ECGDB/Band_pass/2/ECG_bandpass_10.csv
# D:/Data/ECGDB/Band_pass/2/ECG_bandpass_11.csv
# D:/Data/ECGDB/Band_pass/2/ECG_bandpass_12.csv
# D:/Data/ECGDB/Band_pass/2/ECG_bandpass_13.csv
# D:/Data/ECGDB/Band_pass/2/ECG_bandpass_14.csv
# D:/Data/ECGDB/Band_pass/2/ECG_bandpass_15.csv
# D:/Data/ECGDB/Band_pass/2/ECG_bandpass_16.csv
# D:/Data/ECGDB/Band_pass/2/ECG_bandpass_17.csv
# D:/Data/ECGDB/Band_pass/2/ECG_bandpass_18.csv
# D:/Data/ECGDB/Band_pass/2/ECG_bandpass_19.csv
# D:/Data/ECGDB/Band_pass/2/ECG_bandpass_20.csv
# D:/Data/ECGDB/Band_pass/2/ECG_bandpass_21.csv
# D:/Data/ECGDB/Band_pass/2/ECG_bandpass_22.csv
# D:/Data/ECGDB/Band_pass/2/ECG_bandpass_23.csv
# D:/Data/ECGDB/Band_pass/2/ECG_bandpass_24.csv
# D:/Data/ECGDB/Band_pass/2/ECG_bandpass_25.csv
# D:/Data/ECGDB/Band_pass/2/ECG_bandpass_26.csv
# D:/Data/ECGDB/Band_pass/2/ECG_bandpass_27.csv
# D:/Data/ECGDB/Band_pass/2/ECG_bandpass_28.csv
# D:/Data/ECGDB/Band_pass/2/ECG_bandpass_29.csv
# D:/Data/ECGDB/Band_pass/2/ECG_bandpass_30.csv
# D:/Data/ECGDB/Band_pass/2/ECG_bandpass_31.csv
# D:/Data/ECGDB/Band_pass/2/ECG_bandpass_32.csv
# D:/Data/ECGDB/Band_pass/2/ECG_bandpass_33.csv
# D:/Data/ECGDB/Band_pass/2/ECG_bandpass_34.csv
# D:/Data/ECGDB/Band_pass/2/ECG_bandpass_35.csv
# D:/Data/ECGDB/Band_pass/2/ECG_bandpass_36.csv
# D:/Data/ECGDB/Band_pass/2/ECG_bandpass_37.csv
# D:/Data/ECGDB/Band_pass/2/ECG_bandpass_38.csv
# D:/Data/ECGDB/Band_pass/2/ECG_bandpass_39.csv
# D:/Data/ECGDB/Band_pass/2/ECG_bandpass_40.csv
# D:/Data/ECGDB/Band_pass/2/ECG_bandpass_41.csv
# D:/Data/ECGDB/Band_pass/2/ECG_bandpass_42.csv
# D:/Data/ECGDB/Band_pass/2/ECG_bandpass_43.csv
# D:/Data/ECGDB/Band_pass/2/ECG_bandpass_44.csv
# D:/Data/ECGDB/Band_pass/2/ECG_bandpass_45.csv
# D:/Data/ECGDB/Band_pass/2/ECG_bandpass_46.csv
# D:/Data/ECGDB/Band_pass/2/ECG_bandpass_47.csv
# D:/Data/ECGDB/Band_pass/2/ECG_bandpass_48.csv
# D:/Data/ECGDB/Band_pass/2/ECG_bandpass_49.csv
# D:/Data/ECGDB/Band_pass/2/ECG_bandpass_50.csv
# D:/Data/ECGDB/Band_pass/2/ECG_bandpass_51.csv
# D:/Data/ECGDB/Band_pass/2/ECG_bandpass_52.csv
# D:/Data/ECGDB/Band_pass/2/ECG_bandpass_53.csv
# D:/Data/ECGDB/Band_pass/2/ECG_bandpass_54.csv
# D:/Data/ECGDB/Band_pass/2/ECG_bandpass_55.csv
# D:/Data/ECGDB/Band_pass/2/ECG_bandpass_56.csv
# D:/Data/ECGDB/Band_pass/2/ECG_bandpass_57.csv
# D:/Data/ECGDB/Band_pass/2/ECG_bandpass_58.csv
# D:/Data/ECGDB/Band_pass/2/ECG_bandpass_59.csv
# D:/Data/ECGDB/Band_pass/2/ECG_bandpass_60.csv
# D:/Data/ECGDB/Band_pass/3/ECG_bandpass_1.csv
# D:/Data/ECGDB/Band_pass/3/ECG_bandpass_2.csv
# D:/Data/ECGDB/Band_pass/3/ECG_bandpass_3.csv
# D:/Data/ECGDB/Band_pass/3/ECG_bandpass_4.csv
# D:/Data/ECGDB/Band_pass/3/ECG_bandpass_5.csv
# D:/Data/ECGDB/Band_pass/3/ECG_bandpass_6.csv
# D:/Data/ECGDB/Band_pass/3/ECG_bandpass_7.csv
# D:/Data/ECGDB/Band_pass/3/ECG_bandpass_8.csv
# D:/Data/ECGDB/Band_pass/3/ECG_bandpass_9.csv
# D:/Data/ECGDB/Band_pass/3/ECG_bandpass_10.csv
# D:/Data/ECGDB/Band_pass/3/ECG_bandpass_11.csv
# D:/Data/ECGDB/Band_pass/3/ECG_bandpass_12.csv
# D:/Data/ECGDB/Band_pass/3/ECG_bandpass_13.csv
# D:/Data/ECGDB/Band_pass/3/ECG_bandpass_14.csv
# D:/Data/ECGDB/Band_pass/3/ECG_bandpass_15.csv
# D:/Data/ECGDB/Band_pass/3/ECG_bandpass_16.csv
# D:/Data/ECGDB/Band_pass/3/ECG_bandpass_17.csv
# D:/Data/ECGDB/Band_pass/3/ECG_bandpass_18.csv
# D:/Data/ECGDB/Band_pass/3/ECG_bandpass_19.csv
# D:/Data/ECGDB/Band_pass/3/ECG_bandpass_20.csv
# D:/Data/ECGDB/Band_pass/3/ECG_bandpass_21.csv
# D:/Data/ECGDB/Band_pass/3/ECG_bandpass_22.csv
# D:/Data/ECGDB/Band_pass/3/ECG_bandpass_23.csv
# D:/Data/ECGDB/Band_pass/3/ECG_bandpass_24.csv
# D:/Data/ECGDB/Band_pass/3/ECG_bandpass_25.csv
# D:/Data/ECGDB/Band_pass/3/ECG_bandpass_26.csv
# D:/Data/ECGDB/Band_pass/3/ECG_bandpass_27.csv
# D:/Data/ECGDB/Band_pass/3/ECG_bandpass_28.csv
# D:/Data/ECGDB/Band_pass/3/ECG_bandpass_29.csv
# D:/Data/ECGDB/Band_pass/3/ECG_bandpass_30.csv
# D:/Data/ECGDB/Band_pass/3/ECG_bandpass_31.csv
# D:/Data/ECGDB/Band_pass/3/ECG_bandpass_32.csv
# D:/Data/ECGDB/Band_pass/3/ECG_bandpass_33.csv
# D:/Data/ECGDB/Band_pass/3/ECG_bandpass_34.csv
# D:/Data/ECGDB/Band_pass/3/ECG_bandpass_35.csv
# D:/Data/ECGDB/Band_pass/3/ECG_bandpass_36.csv
# D:/Data/ECGDB/Band_pass/3/ECG_bandpass_37.csv
# D:/Data/ECGDB/Band_pass/3/ECG_bandpass_38.csv
# D:/Data/ECGDB/Band_pass/3/ECG_bandpass_39.csv
# D:/Data/ECGDB/Band_pass/3/ECG_bandpass_40.csv
# D:/Data/ECGDB/Band_pass/3/ECG_bandpass_41.csv
# D:/Data/ECGDB/Band_pass/3/ECG_bandpass_42.csv
# D:/Data/ECGDB/Band_pass/3/ECG_bandpass_43.csv
# D:/Data/ECGDB/Band_pass/3/ECG_bandpass_44.csv
# D:/Data/ECGDB/Band_pass/3/ECG_bandpass_45.csv
# D:/Data/ECGDB/Band_pass/3/ECG_bandpass_46.csv
# D:/Data/ECGDB/Band_pass/3/ECG_bandpass_47.csv
# D:/Data/ECGDB/Band_pass/3/ECG_bandpass_48.csv
# D:/Data/ECGDB/Band_pass/3/ECG_bandpass_49.csv
# D:/Data/ECGDB/Band_pass/3/ECG_bandpass_50.csv
# D:/Data/ECGDB/Band_pass/3/ECG_bandpass_51.csv
# D:/Data/ECGDB/Band_pass/3/ECG_bandpass_52.csv
# D:/Data/ECGDB/Band_pass/3/ECG_bandpass_53.csv
# D:/Data/ECGDB/Band_pass/3/ECG_bandpass_54.csv
# D:/Data/ECGDB/Band_pass/3/ECG_bandpass_55.csv
# D:/Data/ECGDB/Band_pass/3/ECG_bandpass_56.csv
# D:/Data/ECGDB/Band_pass/3/ECG_bandpass_57.csv
# D:/Data/ECGDB/Band_pass/3/ECG_bandpass_58.csv
# D:/Data/ECGDB/Band_pass/3/ECG_bandpass_59.csv
# D:/Data/ECGDB/Band_pass/3/ECG_bandpass_60.csv
# D:/Data/ECGDB/Band_pass/4/ECG_bandpass_1.csv
# D:/Data/ECGDB/Band_pass/4/ECG_bandpass_2.csv
# D:/Data/ECGDB/Band_pass/4/ECG_bandpass_3.csv
# D:/Data/ECGDB/Band_pass/4/ECG_bandpass_4.csv
# D:/Data/ECGDB/Band_pass/4/ECG_bandpass_5.csv
# D:/Data/ECGDB/Band_pass/4/ECG_bandpass_6.csv
# D:/Data/ECGDB/Band_pass/4/ECG_bandpass_7.csv
# D:/Data/ECGDB/Band_pass/4/ECG_bandpass_8.csv
# D:/Data/ECGDB/Band_pass/4/ECG_bandpass_9.csv
# D:/Data/ECGDB/Band_pass/4/ECG_bandpass_10.csv
# D:/Data/ECGDB/Band_pass/4/ECG_bandpass_11.csv
# D:/Data/ECGDB/Band_pass/4/ECG_bandpass_12.csv
# D:/Data/ECGDB/Band_pass/4/ECG_bandpass_13.csv
# D:/Data/ECGDB/Band_pass/4/ECG_bandpass_14.csv
# D:/Data/ECGDB/Band_pass/4/ECG_bandpass_15.csv
# D:/Data/ECGDB/Band_pass/4/ECG_bandpass_16.csv
# D:/Data/ECGDB/Band_pass/4/ECG_bandpass_17.csv
# D:/Data/ECGDB/Band_pass/4/ECG_bandpass_18.csv
# D:/Data/ECGDB/Band_pass/4/ECG_bandpass_19.csv
# D:/Data/ECGDB/Band_pass/4/ECG_bandpass_20.csv
# D:/Data/ECGDB/Band_pass/4/ECG_bandpass_21.csv
# D:/Data/ECGDB/Band_pass/4/ECG_bandpass_22.csv
# D:/Data/ECGDB/Band_pass/4/ECG_bandpass_23.csv
# D:/Data/ECGDB/Band_pass/4/ECG_bandpass_24.csv
# D:/Data/ECGDB/Band_pass/4/ECG_bandpass_25.csv
# D:/Data/ECGDB/Band_pass/4/ECG_bandpass_26.csv
# D:/Data/ECGDB/Band_pass/4/ECG_bandpass_27.csv
# D:/Data/ECGDB/Band_pass/4/ECG_bandpass_28.csv
# D:/Data/ECGDB/Band_pass/4/ECG_bandpass_29.csv
# D:/Data/ECGDB/Band_pass/4/ECG_bandpass_30.csv
# D:/Data/ECGDB/Band_pass/4/ECG_bandpass_31.csv
# D:/Data/ECGDB/Band_pass/4/ECG_bandpass_32.csv
# D:/Data/ECGDB/Band_pass/4/ECG_bandpass_33.csv
# D:/Data/ECGDB/Band_pass/4/ECG_bandpass_34.csv
# D:/Data/ECGDB/Band_pass/4/ECG_bandpass_35.csv
# D:/Data/ECGDB/Band_pass/4/ECG_bandpass_36.csv
# D:/Data/ECGDB/Band_pass/4/ECG_bandpass_37.csv
# D:/Data/ECGDB/Band_pass/4/ECG_bandpass_38.csv
# D:/Data/ECGDB/Band_pass/4/ECG_bandpass_39.csv
# D:/Data/ECGDB/Band_pass/4/ECG_bandpass_40.csv
# D:/Data/ECGDB/Band_pass/4/ECG_bandpass_41.csv
# D:/Data/ECGDB/Band_pass/4/ECG_bandpass_42.csv
# D:/Data/ECGDB/Band_pass/4/ECG_bandpass_43.csv
# D:/Data/ECGDB/Band_pass/4/ECG_bandpass_44.csv
# D:/Data/ECGDB/Band_pass/4/ECG_bandpass_45.csv
# D:/Data/ECGDB/Band_pass/4/ECG_bandpass_46.csv
# D:/Data/ECGDB/Band_pass/4/ECG_bandpass_47.csv
# D:/Data/ECGDB/Band_pass/4/ECG_bandpass_48.csv
# D:/Data/ECGDB/Band_pass/4/ECG_bandpass_49.csv
# D:/Data/ECGDB/Band_pass/4/ECG_bandpass_50.csv
# D:/Data/ECGDB/Band_pass/4/ECG_bandpass_51.csv
# D:/Data/ECGDB/Band_pass/4/ECG_bandpass_52.csv
# D:/Data/ECGDB/Band_pass/4/ECG_bandpass_53.csv
# D:/Data/ECGDB/Band_pass/4/ECG_bandpass_54.csv
# D:/Data/ECGDB/Band_pass/4/ECG_bandpass_55.csv
# D:/Data/ECGDB/Band_pass/4/ECG_bandpass_56.csv
# D:/Data/ECGDB/Band_pass/4/ECG_bandpass_57.csv
# D:/Data/ECGDB/Band_pass/4/ECG_bandpass_58.csv
# D:/Data/ECGDB/Band_pass/4/ECG_bandpass_59.csv
# D:/Data/ECGDB/Band_pass/4/ECG_bandpass_60.csv
# D:/Data/ECGDB/Band_pass/5/ECG_bandpass_1.csv
# D:/Data/ECGDB/Band_pass/5/ECG_bandpass_2.csv
# D:/Data/ECGDB/Band_pass/5/ECG_bandpass_3.csv
# D:/Data/ECGDB/Band_pass/5/ECG_bandpass_4.csv
# D:/Data/ECGDB/Band_pass/5/ECG_bandpass_5.csv
# D:/Data/ECGDB/Band_pass/5/ECG_bandpass_6.csv
# D:/Data/ECGDB/Band_pass/5/ECG_bandpass_7.csv
# D:/Data/ECGDB/Band_pass/5/ECG_bandpass_8.csv
# D:/Data/ECGDB/Band_pass/5/ECG_bandpass_9.csv
# D:/Data/ECGDB/Band_pass/5/ECG_bandpass_10.csv
# D:/Data/ECGDB/Band_pass/5/ECG_bandpass_11.csv
# D:/Data/ECGDB/Band_pass/5/ECG_bandpass_12.csv
# D:/Data/ECGDB/Band_pass/5/ECG_bandpass_13.csv
# D:/Data/ECGDB/Band_pass/5/ECG_bandpass_14.csv
# D:/Data/ECGDB/Band_pass/5/ECG_bandpass_15.csv
# D:/Data/ECGDB/Band_pass/5/ECG_bandpass_16.csv
# D:/Data/ECGDB/Band_pass/5/ECG_bandpass_17.csv
# D:/Data/ECGDB/Band_pass/5/ECG_bandpass_18.csv
# D:/Data/ECGDB/Band_pass/5/ECG_bandpass_19.csv
# D:/Data/ECGDB/Band_pass/5/ECG_bandpass_20.csv
# D:/Data/ECGDB/Band_pass/5/ECG_bandpass_21.csv
# D:/Data/ECGDB/Band_pass/5/ECG_bandpass_22.csv
# D:/Data/ECGDB/Band_pass/5/ECG_bandpass_23.csv
# D:/Data/ECGDB/Band_pass/5/ECG_bandpass_24.csv
# D:/Data/ECGDB/Band_pass/5/ECG_bandpass_25.csv
# D:/Data/ECGDB/Band_pass/5/ECG_bandpass_26.csv
# D:/Data/ECGDB/Band_pass/5/ECG_bandpass_27.csv
# D:/Data/ECGDB/Band_pass/5/ECG_bandpass_28.csv
# D:/Data/ECGDB/Band_pass/5/ECG_bandpass_29.csv
# D:/Data/ECGDB/Band_pass/5/ECG_bandpass_30.csv
# D:/Data/ECGDB/Band_pass/5/ECG_bandpass_31.csv
# D:/Data/ECGDB/Band_pass/5/ECG_bandpass_32.csv
# D:/Data/ECGDB/Band_pass/5/ECG_bandpass_33.csv
# D:/Data/ECGDB/Band_pass/5/ECG_bandpass_34.csv
# D:/Data/ECGDB/Band_pass/5/ECG_bandpass_35.csv
# D:/Data/ECGDB/Band_pass/5/ECG_bandpass_36.csv
# D:/Data/ECGDB/Band_pass/5/ECG_bandpass_37.csv
# D:/Data/ECGDB/Band_pass/5/ECG_bandpass_38.csv
# D:/Data/ECGDB/Band_pass/5/ECG_bandpass_39.csv
# D:/Data/ECGDB/Band_pass/5/ECG_bandpass_40.csv
# D:/Data/ECGDB/Band_pass/5/ECG_bandpass_41.csv
# D:/Data/ECGDB/Band_pass/5/ECG_bandpass_42.csv
# D:/Data/ECGDB/Band_pass/5/ECG_bandpass_43.csv
# D:/Data/ECGDB/Band_pass/5/ECG_bandpass_44.csv
# D:/Data/ECGDB/Band_pass/5/ECG_bandpass_45.csv
# D:/Data/ECGDB/Band_pass/5/ECG_bandpass_46.csv
# D:/Data/ECGDB/Band_pass/5/ECG_bandpass_47.csv
# D:/Data/ECGDB/Band_pass/5/ECG_bandpass_48.csv
# D:/Data/ECGDB/Band_pass/5/ECG_bandpass_49.csv
# D:/Data/ECGDB/Band_pass/5/ECG_bandpass_50.csv
# D:/Data/ECGDB/Band_pass/5/ECG_bandpass_51.csv
# D:/Data/ECGDB/Band_pass/5/ECG_bandpass_52.csv
# D:/Data/ECGDB/Band_pass/5/ECG_bandpass_53.csv
# D:/Data/ECGDB/Band_pass/5/ECG_bandpass_54.csv
# D:/Data/ECGDB/Band_pass/5/ECG_bandpass_55.csv
# D:/Data/ECGDB/Band_pass/5/ECG_bandpass_56.csv
# D:/Data/ECGDB/Band_pass/5/ECG_bandpass_57.csv
# D:/Data/ECGDB/Band_pass/5/ECG_bandpass_58.csv
# D:/Data/ECGDB/Band_pass/5/ECG_bandpass_59.csv
# D:/Data/ECGDB/Band_pass/5/ECG_bandpass_60.csv

# %%
ECG = pd.read_csv('D:/Data/ECGDB/one_cycle/2/one_cycle_1.csv')
E = ECG.transpose()
plt.plot(E)

# %%
from tensorflow.keras import models, layers, optimizers, callbacks
X_train = ECG.values[:, :-1]
y_train = E.values[:,-1].astype(int)

# %%
X_train = np.expand_dims(X_train, 2)

print(X_train.shape)
# Out:
# (1, 301, 1)

# %%
from tensorflow.keras import utils
y_train = utils.to_categorical(y_train)

print(y_train.shape)
# Out:
# (302, 1)

# %%
# X_train, y_train = get_train_test()

X_train = X_train.reshape(X_train.shape[0],301,1)
# X_test = X_test.reshape(X_test.shape[0],301,1)

# %%
def get_model():
    model = Sequential()

    model.add(Conv1D(filters=128,kernel_size=3,activation='relu', input_shape=(301,1)))
    model.add(Conv1D(filters=64,kernel_size=3,activation='relu'))
    model.add(Conv1D(filters=32,kernel_size=3,activation='relu'))
    model.add(MaxPooling1D(pool_size=2, strides=None))

    model.add(Flatten())

    model.add(Dense(100, activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(20, activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(1))
    
    return model

    
model = get_model()           
model.compile(optimizer='adam', loss='mse',metrics=['accuracy'])
# model.build(input_shape)
model.summary()
model.build(input_shape=(301,1))
history = model.fit(X_train, X_train, batch_size = 64, epochs = 100, verbose = 1)
# Out:
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_33 (Conv1D)          (None, 299, 128)          512
#
#  conv1d_34 (Conv1D)          (None, 297, 64)           24640
#
#  conv1d_35 (Conv1D)          (None, 295, 32)           6176
#
#  max_pooling1d_11 (MaxPoolin  (None, 147, 32)          0
#  g1D)
#
#  flatten_8 (Flatten)         (None, 4704)              0
#
#  dense_29 (Dense)            (None, 100)               470500
#
#  dropout_15 (Dropout)        (None, 100)               0
#
#  dense_30 (Dense)            (None, 20)                2020
#
#  dropout_16 (Dropout)        (None, 20)                0
#
#  dense_31 (Dense)            (None, 1)                 21
#
# =================================================================
# Total params: 503,869
# Trainable params: 503,869
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 1/1 [==============================] - 0s 312ms/step - loss: 0.0397 - accuracy: 0.0033
# Epoch 2/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0319 - accuracy: 0.0033
# Epoch 3/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0309 - accuracy: 0.0033
# Epoch 4/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0309 - accuracy: 0.0033
# Epoch 5/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0234 - accuracy: 0.0033
# Epoch 6/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0419 - accuracy: 0.0033
# Epoch 7/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0284 - accuracy: 0.0033
# Epoch 8/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0470 - accuracy: 0.0033
# Epoch 9/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0239 - accuracy: 0.0033
# Epoch 10/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0286 - accuracy: 0.0033
# Epoch 11/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0320 - accuracy: 0.0033
# Epoch 12/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0410 - accuracy: 0.0033
# Epoch 13/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0277 - accuracy: 0.0033
# Epoch 14/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0344 - accuracy: 0.0033
# Epoch 15/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0177 - accuracy: 0.0033
# Epoch 16/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0191 - accuracy: 0.0033
# Epoch 17/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0280 - accuracy: 0.0033
# Epoch 18/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0130 - accuracy: 0.0033
# Epoch 19/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0226 - accuracy: 0.0033
# Epoch 20/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0141 - accuracy: 0.0033
# Epoch 21/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0134 - accuracy: 0.0033
# Epoch 22/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0291 - accuracy: 0.0033
# Epoch 23/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0439 - accuracy: 0.0033
# Epoch 24/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0132 - accuracy: 0.0033
# Epoch 25/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0308 - accuracy: 0.0033
# Epoch 26/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0145 - accuracy: 0.0033
# Epoch 27/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0194 - accuracy: 0.0033
# Epoch 28/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0191 - accuracy: 0.0033
# Epoch 29/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0140 - accuracy: 0.0033
# Epoch 30/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0309 - accuracy: 0.0033
# Epoch 31/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0148 - accuracy: 0.0033
# Epoch 32/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0136 - accuracy: 0.0033
# Epoch 33/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0196 - accuracy: 0.0033
# Epoch 34/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0128 - accuracy: 0.0033
# Epoch 35/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0341 - accuracy: 0.0033
# Epoch 36/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0159 - accuracy: 0.0033
# Epoch 37/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0131 - accuracy: 0.0033
# Epoch 38/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0129 - accuracy: 0.0033
# Epoch 39/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0153 - accuracy: 0.0033
# Epoch 40/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0146 - accuracy: 0.0033
# Epoch 41/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0213 - accuracy: 0.0033
# Epoch 42/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0139 - accuracy: 0.0033
# Epoch 43/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0150 - accuracy: 0.0033
# Epoch 44/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0128 - accuracy: 0.0033
# Epoch 45/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0144 - accuracy: 0.0033
# Epoch 46/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0215 - accuracy: 0.0033
# Epoch 47/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0134 - accuracy: 0.0033
# Epoch 48/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0149 - accuracy: 0.0033
# Epoch 49/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0168 - accuracy: 0.0033
# Epoch 50/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0152 - accuracy: 0.0033
# Epoch 51/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0130 - accuracy: 0.0033
# Epoch 52/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0210 - accuracy: 0.0033
# Epoch 53/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0143 - accuracy: 0.0033
# Epoch 54/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0201 - accuracy: 0.0033
# Epoch 55/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0170 - accuracy: 0.0033
# Epoch 56/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0183 - accuracy: 0.0033
# Epoch 57/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0135 - accuracy: 0.0033
# Epoch 58/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0147 - accuracy: 0.0033
# Epoch 59/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0133 - accuracy: 0.0033
# Epoch 60/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0193 - accuracy: 0.0033
# Epoch 61/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0138 - accuracy: 0.0033
# Epoch 62/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0145 - accuracy: 0.0033
# Epoch 63/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0174 - accuracy: 0.0033
# Epoch 64/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0131 - accuracy: 0.0033
# Epoch 65/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0128 - accuracy: 0.0033
# Epoch 66/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0151 - accuracy: 0.0033
# Epoch 67/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0224 - accuracy: 0.0033
# Epoch 68/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0147 - accuracy: 0.0033
# Epoch 69/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0131 - accuracy: 0.0033
# Epoch 70/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0154 - accuracy: 0.0033
# Epoch 71/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0149 - accuracy: 0.0033
# Epoch 72/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0129 - accuracy: 0.0033
# Epoch 73/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0181 - accuracy: 0.0033
# Epoch 74/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0131 - accuracy: 0.0033
# Epoch 75/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0131 - accuracy: 0.0033
# Epoch 76/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0131 - accuracy: 0.0033
# Epoch 77/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0156 - accuracy: 0.0033
# Epoch 78/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0134 - accuracy: 0.0033
# Epoch 79/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0128 - accuracy: 0.0033
# Epoch 80/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0135 - accuracy: 0.0033
# Epoch 81/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0153 - accuracy: 0.0033
# Epoch 82/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0141 - accuracy: 0.0033
# Epoch 83/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0130 - accuracy: 0.0033
# Epoch 84/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0143 - accuracy: 0.0033
# Epoch 85/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0131 - accuracy: 0.0033
# Epoch 86/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0170 - accuracy: 0.0033
# Epoch 87/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0145 - accuracy: 0.0033
# Epoch 88/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0129 - accuracy: 0.0033
# Epoch 89/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0138 - accuracy: 0.0033
# Epoch 90/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0212 - accuracy: 0.0033
# Epoch 91/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0128 - accuracy: 0.0033
# Epoch 92/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0132 - accuracy: 0.0033
# Epoch 93/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0162 - accuracy: 0.0033
# Epoch 94/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0133 - accuracy: 0.0033
# Epoch 95/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0130 - accuracy: 0.0033
# Epoch 96/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0151 - accuracy: 0.0033
# Epoch 97/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0142 - accuracy: 0.0033
# Epoch 98/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0156 - accuracy: 0.0033
# Epoch 99/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0128 - accuracy: 0.0033
# Epoch 100/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0175 - accuracy: 0.0033

# %%
from sklearn.metrics import classification_report, confusion_matrix

# Test Model
predY = model.predict(X_test)
y_pred = np.argmax(predY,axis=1)
y_actual = np.argmax(y_test,axis=1)
cm = confusion_matrix(y_actual, y_pred)
print(cm)
